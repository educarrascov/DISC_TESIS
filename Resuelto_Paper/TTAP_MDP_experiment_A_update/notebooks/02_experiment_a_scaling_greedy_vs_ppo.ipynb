# %% [markdown]
# # Experimento A dinámico: Greedy online vs. MaskablePPO
#
# Este notebook amplía la comparación a la familia de escalamiento: 4 áreas / 4 helicópteros / 2 a 60 tareas.
#
# La geometría, las capacidades, las velocidades, la exigencia visual y el generador anidado de tareas son los mismos del Experimento A.
#
# Se comparan únicamente **Greedy online** y **MaskablePPO** dentro del MDP estocástico.
#
# La curva de aprendizaje es solo un diagnóstico. La evidencia principal es el desempeño de la política congelada sobre 30 instancias que PPO no vio durante el entrenamiento.

# %%
from pathlib import Path
import platform
import sys
import time
import warnings

project_root = Path.cwd().resolve()
if project_root.name == "notebooks":
    project_root = project_root.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from ttap_mdp import (
    EXPERIMENT_A_GENERATOR_VERSION,
    EXPERIMENT_A_INSTANCE_SEEDS,
    EXPERIMENT_A_TASK_COUNTS,
    ExperimentAFamilyEnv,
    TTAPGymEnv,
    UncertaintyConfig,
    build_experiment_a_scenario,
    run_episode,
)
from ttap_mdp.baselines import GreedyOnlinePolicy

warnings.filterwarnings("ignore", category=FutureWarning)
pd.set_option("display.max_columns", 50)
pd.set_option("display.width", 180)

print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("Project root:", project_root)
print("Generator:", EXPERIMENT_A_GENERATOR_VERSION)
# Out:
# Python: 3.11.3
# Platform: macOS-26.5.2-arm64-arm-64bit
# Project root: /Users/educarrascovidal/Documentos/GitHub/Tesis_Doctoral/DISC_TESIS/Resuelto_Paper/TTAP_MDP_experiment_A_update
# Generator: matched_v2_heterogeneous

# %% [markdown]
# ## 1. Panel de control
#
# Ejecuta primero `MODE = "pilot"`. Este modo recorre los cinco tamaños,
# entrena una política por tamaño y evalúa las 30 instancias, pero con menos
# pasos y una sola semilla PPO.
#
# Cuando el piloto esté revisado, cambia a `MODE = "formal"`:
#
# - tres semillas independientes de entrenamiento;
# - más pasos por política;
# - cinco realizaciones estocásticas por instancia;
# - 30 instancias de evaluación por tamaño.
#
# Los modelos y CSV se guardan después de cada etapa, de modo que puedes
# detener y continuar sin perder el progreso.

# %%
MODE = "diagnostic_v2"

RETRAIN_MISSING_ONLY = False
RUN_TRAINING = True
RUN_EVALUATION = True

# Primero se prueban los extremos.
TASK_SIZES = [20, 30, 40, 50, 60]

TRAIN_INSTANCE_SEEDS = list(range(1001, 1061))

# En esta corrida actúan como validación diagnóstica.
EVAL_INSTANCE_SEEDS = list(range(1, 31))

PPO_TRAIN_SEEDS = [218, 219, 220]

TRAIN_TIMESTEPS = 500_000
EVAL_REPLICATES = 1

REWARD_SCALE = 100.0
OBS_VERSION = "obsV2"
REWARD_VERSION = "priorityV1"
GAMMA = 1.0

uncertainty = UncertaintyConfig.moderate()

model_dir = (
    project_root
    / "models"
    / "experiment_a_scaling"
    / MODE
)

result_dir = (
    project_root
    / "results"
    / "experiment_a_scaling"
    / MODE
)

model_dir.mkdir(parents=True, exist_ok=True)
result_dir.mkdir(parents=True, exist_ok=True)

evaluation_path = result_dir / f"evaluation_{MODE}.csv"
training_index_path = result_dir / f"training_index_{MODE}.csv"

# %%
test_scenario = build_experiment_a_scenario(20, 1)

test_env = TTAPGymEnv(
    test_scenario,
    uncertainty,
    reward_scale=100.0,
)

observation, info = test_env.reset(seed=218)

expected_observation_length = (
    2
    + 9 * len(test_scenario.helicopters)
    + 9 * len(test_scenario.tasks)
)

assert observation.shape == (expected_observation_length,)
assert test_env.observation_space.contains(observation)
assert np.isfinite(observation).all()
assert observation.min() >= 0.0
assert observation.max() <= 1.0
assert len(info["action_mask"]) == test_env.action_space.n

print("Observación:", observation.shape)
print("Acciones:", test_env.action_space.n)
print("Verificación obsV2 correcta.")
# Out:
# Observación: (218,)
# Acciones: 85
# Verificación obsV2 correcta.

# %% [markdown]
# ### Separación entrenamiento–evaluación
#
# - PPO aprende usando instancias `1001–1060`.
# - La comparación final usa exclusivamente las instancias `1–30`.
# - Durante la evaluación los pesos de PPO permanecen congelados.
#
# Esta separación evita medir memorización. Las cinco cargas de una misma
# semilla son anidadas: la instancia de 20 tareas es el prefijo de la de 60.

# %%
assert set(TRAIN_INSTANCE_SEEDS).isdisjoint(EVAL_INSTANCE_SEEDS)
assert TASK_SIZES == [20, 30, 40, 50, 60]
assert EVAL_INSTANCE_SEEDS == list(range(1, 31))

example = build_experiment_a_scenario(20, 1)
nodes_table = pd.DataFrame(
    [
        {
            "Node": node.node_id,
            "x (km)": node.first_coordinate,
            "y (km)": node.second_coordinate,
            "Role": "Base" if node.is_base else "Demand area",
        }
        for node in example.nodes
    ]
)
fleet_table = pd.DataFrame(
    [
        {
            "Helicopter": helicopter.helicopter_id,
            "Visual": helicopter.visual_capable,
            "Cargo": helicopter.capacity.cargo,
            "Medical": helicopter.capacity.medical,
            "Personnel": helicopter.capacity.personnel,
            "Speed (km/h)": helicopter.speed_kmh,
        }
        for helicopter in example.helicopters
    ]
)
display(nodes_table)
display(fleet_table)
# Out:
#    Node  x (km)  y (km)         Role
# 0  BASE     0.0     0.0         Base
# 1     A    10.0     5.0  Demand area
# 2     B    20.0    15.0  Demand area
# 3     C    30.0    10.0  Demand area
# 4     D    40.0    20.0  Demand area
#   Helicopter  Visual  Cargo  Medical  Personnel  Speed (km/h)
# 0         H1    True    500        3          3           150
# 1         H2   False    500        3          3           120
# 2         H3    True    500        3          3           140
# 3         H4   False    500        3          3           160

# %%
validation_rows = []
for instance_seed in EVAL_INSTANCE_SEEDS:
    scenario_60 = build_experiment_a_scenario(60, instance_seed)
    for n_tasks in TASK_SIZES:
        scenario_n = build_experiment_a_scenario(n_tasks, instance_seed)
        assert scenario_n.tasks == scenario_60.tasks[:n_tasks]
        counts = pd.Series(
            [task.node_id for task in scenario_n.tasks]
        ).value_counts()
        validation_rows.append(
            {
                "Tasks": n_tasks,
                "Instance seed": instance_seed,
                "All areas represented": set(counts.index)
                == {"A", "B", "C", "D"},
                "Largest-smallest area load": int(
                    counts.max() - counts.min()
                ),
            }
        )

validation = pd.DataFrame(validation_rows)
assert validation["All areas represented"].all()
print("Validated nested scenarios:", len(validation))
validation.groupby("Tasks").agg(
    instances=("Instance seed", "nunique"),
    minimum_imbalance=("Largest-smallest area load", "min"),
    maximum_imbalance=("Largest-smallest area load", "max"),
)
# Out:
# Validated nested scenarios: 150
#        instances  minimum_imbalance  maximum_imbalance
# Tasks
# 20            30                  4                 13
# 30            30                  7                 16
# 40            30                  8                 19
# 50            30                 12                 23
# 60            30                 15                 28

# %% [markdown]
# ## 2. Por qué se entrena un PPO por tamaño
#
# En esta implementación el vector de estado contiene nueve valores por
# tarea y el catálogo contiene una asignación por par
# helicóptero–tarea:
#
# $
# |\text{obs}|=2+7|H|+9|I|,\qquad
# |\mathcal A|=1+|H|+|H||I|.
# $
#
# Por ello las redes de 20 y 60 tareas tienen entradas y salidas de tamaños
# distintos. Entrenar cinco PPO independientes es la opción más transparente
# para este primer experimento de escalamiento; no se ocultan tareas mediante
# relleno y cada PPO se compara con Greedy en su mismo problema.

# %%
dimension_rows = []
for n_tasks in TASK_SIZES:
    scenario = build_experiment_a_scenario(n_tasks, 1)
    environment = TTAPGymEnv(scenario, uncertainty)
    dimension_rows.append(
        {
            "Tasks": n_tasks,
            "Observation values": environment.observation_space.shape[0],
            "Discrete actions": environment.action_space.n,
        }
    )
    environment.close()
pd.DataFrame(dimension_rows)
# Out:
#    Tasks  Observation values  Discrete actions
# 0     20                 218                85
# 1     30                 308               125
# 2     40                 398               165
# 3     50                 488               205
# 4     60                 578               245

# %% [markdown]
# ## 3. Entrenamiento PPO sobre una familia de instancias
#
# En cada episodio de entrenamiento se selecciona una instancia diferente
# del conjunto `1001–1060`. La política no se entrena contra una sola tabla
# fija de tareas.
#
# Se registra la curva dentro del notebook y se guarda un CSV por modelo.
# TensorBoard no es necesario.

# %%
try:
    from sb3_contrib import MaskablePPO
    from sb3_contrib.common.wrappers import ActionMasker
    from stable_baselines3.common.callbacks import BaseCallback
    from stable_baselines3.common.monitor import Monitor
except ImportError as exc:
    raise ImportError(
        'Faltan dependencias RL. Ejecuta: python -m pip install -e ".[all]"'
    ) from exc


def mask_fn(environment):
    return environment.action_masks()


class TrainingHistoryCallback(BaseCallback):
    def __init__(self, n_tasks, ppo_seed):
        super().__init__(verbose=0)
        self.n_tasks = int(n_tasks)
        self.ppo_seed = int(ppo_seed)
        self.records = []

    def _on_step(self):
        for info, done in zip(
            self.locals.get("infos", []),
            self.locals.get("dones", []),
        ):
            episode = info.get("episode")
            if done and episode is not None:
                self.records.append(
                    {
                        "tasks": self.n_tasks,
                        "ppo_seed": self.ppo_seed,
                        "timestep": int(self.num_timesteps),
                        "episode_return": float(episode["r"]),
                        "episode_length": int(episode["l"]),
                        "instance_seed": int(info["instance_seed"]),
                    }
                )
        return True


def model_stem(n_tasks, ppo_seed):
    return model_dir / (
        f"ppo_T{n_tasks}"
        f"_seed{ppo_seed}"
        f"_steps{TRAIN_TIMESTEPS}"
        f"_gamma{GAMMA:.1f}"
        f"_{OBS_VERSION}"
        f"_{REWARD_VERSION}"
    )


def history_path(n_tasks, ppo_seed):
    return result_dir / (
        f"training_T{n_tasks}"
        f"_seed{ppo_seed}"
        f"_{OBS_VERSION}.csv"
    )

# %%
models = {}
training_frames = []
training_index = []

if RUN_TRAINING:
    total_models = len(TASK_SIZES) * len(PPO_TRAIN_SEEDS)
    completed_models = 0
    for n_tasks in TASK_SIZES:
        for ppo_seed in PPO_TRAIN_SEEDS:
            destination = Path(f"{model_stem(n_tasks, ppo_seed)}.zip")
            csv_path = history_path(n_tasks, ppo_seed)
            start = time.perf_counter()

            if RETRAIN_MISSING_ONLY and destination.exists():
                model = MaskablePPO.load(destination, device="cpu")
                history = (
                    pd.read_csv(csv_path)
                    if csv_path.exists()
                    else pd.DataFrame()
                )
                status = "loaded"
            else:
                family_environment = ExperimentAFamilyEnv(
                    n_tasks,
                    TRAIN_INSTANCE_SEEDS,
                    uncertainty,
                    sampler_seed=ppo_seed,
                    reward_scale=REWARD_SCALE,
                )
                training_environment = Monitor(
                    ActionMasker(family_environment, mask_fn)
                )
                callback = TrainingHistoryCallback(n_tasks, ppo_seed)
                
                policy_kwargs = {
                    "net_arch": {
                        "pi": [256, 256, 128],
                        "vf": [256, 256, 128],
                    }
                }
                
                model = MaskablePPO(
                    "MlpPolicy",
                    training_environment,
                    seed=ppo_seed,
                    learning_rate=3e-4,
                    n_steps=4096,
                    batch_size=256,
                    n_epochs=10,
                    gamma=GAMMA,
                    gae_lambda=0.95,
                    clip_range=0.2,
                    ent_coef=0.01,
                    vf_coef=0.5,
                    max_grad_norm=0.5,
                    policy_kwargs=policy_kwargs,
                    verbose=1,
                    device="cpu",
                )
                model.learn(
                    total_timesteps=TRAIN_TIMESTEPS,
                    callback=callback,
                    progress_bar=True,
                )
                model.save(model_stem(n_tasks, ppo_seed))
                training_environment.close()
                history = pd.DataFrame(callback.records)
                history.to_csv(csv_path, index=False)
                status = "trained"

            models[(n_tasks, ppo_seed)] = model
            if not history.empty:
                training_frames.append(history)
            completed_models += 1
            elapsed = time.perf_counter() - start
            training_index.append(
                {
                    "tasks": n_tasks,
                    "ppo_seed": ppo_seed,
                    "status": status,
                    "timesteps": TRAIN_TIMESTEPS,
                    "elapsed_seconds": elapsed,
                    "model": str(destination),
                    "history": str(csv_path),
                }
            )
            print(
                f"[{completed_models}/{total_models}] "
                f"T={n_tasks}, seed={ppo_seed}: {status} "
                f"({elapsed:.1f} s)"
            )

    pd.DataFrame(training_index).to_csv(training_index_path, index=False)
else:
    for n_tasks in TASK_SIZES:
        for ppo_seed in PPO_TRAIN_SEEDS:
            destination = Path(f"{model_stem(n_tasks, ppo_seed)}.zip")
            if not destination.exists():
                raise FileNotFoundError(destination)
            models[(n_tasks, ppo_seed)] = MaskablePPO.load(
                destination, device="cpu"
            )
            csv_path = history_path(n_tasks, ppo_seed)
            if csv_path.exists():
                training_frames.append(pd.read_csv(csv_path))

training_history = (
    pd.concat(training_frames, ignore_index=True)
    if training_frames
    else pd.DataFrame()
)
print("Models available:", len(models))
print("Training episodes recorded:", len(training_history))
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# /Users/educarrascovidal/Documentos/GitHub/.venv/lib/python3.11/site-packages/rich/live.py:260: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37.8     |
# |    ep_rew_mean     | 28.9     |
# | time/              |          |
# |    fps             | 2203     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.3         |
# |    ep_rew_mean          | 29.4         |
# | time/                   |              |
# |    fps                  | 1880         |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0062522134 |
# |    clip_fraction        | 0.0532       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.00542      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.5          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0201      |
# |    value_loss           | 26.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38.4         |
# |    ep_rew_mean          | 30.1         |
# | time/                   |              |
# |    fps                  | 1797         |
# |    iterations           | 3            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0067266626 |
# |    clip_fraction        | 0.0485       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.777        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.55         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0228      |
# |    value_loss           | 16.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.7        |
# |    ep_rew_mean          | 29.3        |
# | time/                   |             |
# |    fps                  | 1772        |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008428503 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.65        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0289     |
# |    value_loss           | 9.81        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38          |
# |    ep_rew_mean          | 29.6        |
# | time/                   |             |
# |    fps                  | 1712        |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009587994 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0323     |
# |    value_loss           | 5.4         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.8        |
# |    ep_rew_mean          | 29.6        |
# | time/                   |             |
# |    fps                  | 1501        |
# |    iterations           | 6           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009435907 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0336     |
# |    value_loss           | 3.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.1        |
# |    ep_rew_mean          | 30          |
# | time/                   |             |
# |    fps                  | 1512        |
# |    iterations           | 7           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009928624 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0331     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 38.4       |
# |    ep_rew_mean          | 29.4       |
# | time/                   |            |
# |    fps                  | 1514       |
# |    iterations           | 8          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01113008 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.983     |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.637      |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.035     |
# |    value_loss           | 3.03       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.1        |
# |    ep_rew_mean          | 30.6        |
# | time/                   |             |
# |    fps                  | 1508        |
# |    iterations           | 9           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011484245 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.989      |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.551       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0336     |
# |    value_loss           | 2.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.9        |
# |    ep_rew_mean          | 30          |
# | time/                   |             |
# |    fps                  | 1495        |
# |    iterations           | 10          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009694615 |
# |    clip_fraction        | 0.0905      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.677       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0307     |
# |    value_loss           | 2.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.3        |
# |    ep_rew_mean          | 31          |
# | time/                   |             |
# |    fps                  | 1507        |
# |    iterations           | 11          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011249216 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.531       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0334     |
# |    value_loss           | 2.56        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.5        |
# |    ep_rew_mean          | 31.2        |
# | time/                   |             |
# |    fps                  | 1506        |
# |    iterations           | 12          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010487218 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.954      |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.417       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0369     |
# |    value_loss           | 2.07        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38          |
# |    ep_rew_mean          | 30.5        |
# | time/                   |             |
# |    fps                  | 1515        |
# |    iterations           | 13          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.011567179 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.67        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0357     |
# |    value_loss           | 2.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.9        |
# |    ep_rew_mean          | 30.7        |
# | time/                   |             |
# |    fps                  | 1524        |
# |    iterations           | 14          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012730329 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.425       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0337     |
# |    value_loss           | 2.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.5        |
# |    ep_rew_mean          | 30.1        |
# | time/                   |             |
# |    fps                  | 1518        |
# |    iterations           | 15          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.012575051 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.942      |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.366       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0321     |
# |    value_loss           | 2.16        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.9        |
# |    ep_rew_mean          | 30.8        |
# | time/                   |             |
# |    fps                  | 1521        |
# |    iterations           | 16          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010880653 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.372       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.035      |
# |    value_loss           | 1.88        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38          |
# |    ep_rew_mean          | 30.5        |
# | time/                   |             |
# |    fps                  | 1516        |
# |    iterations           | 17          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.012802528 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.894      |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.344       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0364     |
# |    value_loss           | 1.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.6        |
# |    ep_rew_mean          | 30.8        |
# | time/                   |             |
# |    fps                  | 1521        |
# |    iterations           | 18          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010683125 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.537       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0314     |
# |    value_loss           | 2.06        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 38         |
# |    ep_rew_mean          | 31.3       |
# | time/                   |            |
# |    fps                  | 1514       |
# |    iterations           | 19         |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.01128424 |
# |    clip_fraction        | 0.117      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.868     |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.502      |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0322    |
# |    value_loss           | 2.08       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.3        |
# |    ep_rew_mean          | 30.9        |
# | time/                   |             |
# |    fps                  | 1515        |
# |    iterations           | 20          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011649562 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.849      |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.568       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0314     |
# |    value_loss           | 2.48        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.4        |
# |    ep_rew_mean          | 31.1        |
# | time/                   |             |
# |    fps                  | 1517        |
# |    iterations           | 21          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.013121583 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.527       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0312     |
# |    value_loss           | 2.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38          |
# |    ep_rew_mean          | 31.1        |
# | time/                   |             |
# |    fps                  | 1523        |
# |    iterations           | 22          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012665719 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.845      |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.409       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0336     |
# |    value_loss           | 1.81        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38          |
# |    ep_rew_mean          | 30.9        |
# | time/                   |             |
# |    fps                  | 1521        |
# |    iterations           | 23          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.012630036 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.371       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0365     |
# |    value_loss           | 1.5         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 37.5       |
# |    ep_rew_mean          | 31.8       |
# | time/                   |            |
# |    fps                  | 1524       |
# |    iterations           | 24         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.01187009 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.839     |
# |    explained_variance   | 0.972      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.469      |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0376    |
# |    value_loss           | 1.62       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.2        |
# |    ep_rew_mean          | 31.1        |
# | time/                   |             |
# |    fps                  | 1531        |
# |    iterations           | 25          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.013609063 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.822      |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.452       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0333     |
# |    value_loss           | 2.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.9        |
# |    ep_rew_mean          | 31.3        |
# | time/                   |             |
# |    fps                  | 1536        |
# |    iterations           | 26          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.013068043 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.818      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.322       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0348     |
# |    value_loss           | 1.76        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.2        |
# |    ep_rew_mean          | 32.3        |
# | time/                   |             |
# |    fps                  | 1538        |
# |    iterations           | 27          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.013691606 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.813      |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.35        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0347     |
# |    value_loss           | 1.63        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.1        |
# |    ep_rew_mean          | 32.3        |
# | time/                   |             |
# |    fps                  | 1542        |
# |    iterations           | 28          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.014306281 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.81       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.336       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0344     |
# |    value_loss           | 1.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.1        |
# |    ep_rew_mean          | 32.6        |
# | time/                   |             |
# |    fps                  | 1545        |
# |    iterations           | 29          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.009231845 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.799      |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.732       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0318     |
# |    value_loss           | 2.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.5        |
# |    ep_rew_mean          | 31.2        |
# | time/                   |             |
# |    fps                  | 1550        |
# |    iterations           | 30          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.013192095 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.796      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.376       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0334     |
# |    value_loss           | 1.82        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 37.9       |
# |    ep_rew_mean          | 30.8       |
# | time/                   |            |
# |    fps                  | 1555       |
# |    iterations           | 31         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 126976     |
# | train/                  |            |
# |    approx_kl            | 0.01387925 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.817     |
# |    explained_variance   | 0.972      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.313      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.035     |
# |    value_loss           | 1.72       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39.1         |
# |    ep_rew_mean          | 31.9         |
# | time/                   |              |
# |    fps                  | 1556         |
# |    iterations           | 32           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0135644525 |
# |    clip_fraction        | 0.131        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.811       |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.362        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.035       |
# |    value_loss           | 1.59         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.4        |
# |    ep_rew_mean          | 32.3        |
# | time/                   |             |
# |    fps                  | 1559        |
# |    iterations           | 33          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.015926845 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.815      |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.467       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0359     |
# |    value_loss           | 1.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.8        |
# |    ep_rew_mean          | 32          |
# | time/                   |             |
# |    fps                  | 1561        |
# |    iterations           | 34          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.012274051 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.343       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0346     |
# |    value_loss           | 1.68        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.3        |
# |    ep_rew_mean          | 32.9        |
# | time/                   |             |
# |    fps                  | 1559        |
# |    iterations           | 35          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.013161967 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.777      |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.524       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0306     |
# |    value_loss           | 1.59        |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 39       |
# |    ep_rew_mean          | 32.4     |
# | time/                   |          |
# |    fps                  | 1563     |
# |    iterations           | 36       |
# |    time_elapsed         | 94       |
# |    total_timesteps      | 147456   |
# | train/                  |          |
# |    approx_kl            | 0.01227  |
# |    clip_fraction        | 0.121    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.762   |
# |    explained_variance   | 0.97     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.341    |
# |    n_updates            | 350      |
# |    policy_gradient_loss | -0.032   |
# |    value_loss           | 1.65     |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.2        |
# |    ep_rew_mean          | 32.5        |
# | time/                   |             |
# |    fps                  | 1563        |
# |    iterations           | 37          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 151552      |
# | train/                  |             |
# |    approx_kl            | 0.009144179 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.745      |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.389       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0289     |
# |    value_loss           | 1.92        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.6        |
# |    ep_rew_mean          | 32.4        |
# | time/                   |             |
# |    fps                  | 1566        |
# |    iterations           | 38          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.013229866 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.751      |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.331       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0317     |
# |    value_loss           | 1.71        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.3        |
# |    ep_rew_mean          | 33.2        |
# | time/                   |             |
# |    fps                  | 1569        |
# |    iterations           | 39          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 159744      |
# | train/                  |             |
# |    approx_kl            | 0.014580197 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.763      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.361       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0344     |
# |    value_loss           | 1.6         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.4        |
# |    ep_rew_mean          | 32.6        |
# | time/                   |             |
# |    fps                  | 1571        |
# |    iterations           | 40          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.013130078 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.759      |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.299       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0348     |
# |    value_loss           | 1.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.5        |
# |    ep_rew_mean          | 32.9        |
# | time/                   |             |
# |    fps                  | 1573        |
# |    iterations           | 41          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.014742273 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.734      |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.338       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0323     |
# |    value_loss           | 1.66        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.9        |
# |    ep_rew_mean          | 32.8        |
# | time/                   |             |
# |    fps                  | 1575        |
# |    iterations           | 42          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.012941403 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.729      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.24        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0366     |
# |    value_loss           | 1.45        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.2        |
# |    ep_rew_mean          | 33.6        |
# | time/                   |             |
# |    fps                  | 1578        |
# |    iterations           | 43          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.013707882 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.738      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.333       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0316     |
# |    value_loss           | 1.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.6        |
# |    ep_rew_mean          | 32.2        |
# | time/                   |             |
# |    fps                  | 1581        |
# |    iterations           | 44          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.014878157 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.731      |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.366       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0303     |
# |    value_loss           | 1.87        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.7        |
# |    ep_rew_mean          | 31.5        |
# | time/                   |             |
# |    fps                  | 1584        |
# |    iterations           | 45          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.012259088 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.706      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.371       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0298     |
# |    value_loss           | 1.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.7        |
# |    ep_rew_mean          | 31.6        |
# | time/                   |             |
# |    fps                  | 1587        |
# |    iterations           | 46          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.012849387 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.729      |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.279       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0324     |
# |    value_loss           | 1.37        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38           |
# |    ep_rew_mean          | 32.2         |
# | time/                   |              |
# |    fps                  | 1589         |
# |    iterations           | 47           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0142717175 |
# |    clip_fraction        | 0.135        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.723       |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.349        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0321      |
# |    value_loss           | 1.4          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.6        |
# |    ep_rew_mean          | 33.9        |
# | time/                   |             |
# |    fps                  | 1592        |
# |    iterations           | 48          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.015214428 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.709      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.321       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0342     |
# |    value_loss           | 1.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.4        |
# |    ep_rew_mean          | 33          |
# | time/                   |             |
# |    fps                  | 1590        |
# |    iterations           | 49          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.009624859 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.702      |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.541       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0311     |
# |    value_loss           | 1.83        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38          |
# |    ep_rew_mean          | 32.3        |
# | time/                   |             |
# |    fps                  | 1592        |
# |    iterations           | 50          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.011678332 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.274       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0308     |
# |    value_loss           | 1.54        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 36.9       |
# |    ep_rew_mean          | 32.6       |
# | time/                   |            |
# |    fps                  | 1595       |
# |    iterations           | 51         |
# |    time_elapsed         | 130        |
# |    total_timesteps      | 208896     |
# | train/                  |            |
# |    approx_kl            | 0.01567923 |
# |    clip_fraction        | 0.134      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.711     |
# |    explained_variance   | 0.969      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.259      |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0325    |
# |    value_loss           | 1.74       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.7        |
# |    ep_rew_mean          | 32.5        |
# | time/                   |             |
# |    fps                  | 1597        |
# |    iterations           | 52          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.013049354 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.697      |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.306       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0334     |
# |    value_loss           | 1.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.7        |
# |    ep_rew_mean          | 32.1        |
# | time/                   |             |
# |    fps                  | 1599        |
# |    iterations           | 53          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 217088      |
# | train/                  |             |
# |    approx_kl            | 0.017431255 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.719      |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.39        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0344     |
# |    value_loss           | 1.38        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.4        |
# |    ep_rew_mean          | 32.9        |
# | time/                   |             |
# |    fps                  | 1601        |
# |    iterations           | 54          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.016651165 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.697      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.294       |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0358     |
# |    value_loss           | 1.42        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.2        |
# |    ep_rew_mean          | 33.6        |
# | time/                   |             |
# |    fps                  | 1603        |
# |    iterations           | 55          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 225280      |
# | train/                  |             |
# |    approx_kl            | 0.011618333 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.698      |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.277       |
# ...
# |    policy_gradient_loss | -0.0335     |
# |    value_loss           | 1.6         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.6        |
# |    ep_rew_mean          | 32.9        |
# | time/                   |             |
# |    fps                  | 1678        |
# |    iterations           | 72          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.016621292 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.419       |
# |    n_updates            | 710         |
# |    policy_gradient_loss | -0.0354     |
# |    value_loss           | 1.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.1        |
# |    ep_rew_mean          | 32.2        |
# | time/                   |             |
# |    fps                  | 1679        |
# |    iterations           | 73          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 299008      |
# | train/                  |             |
# |    approx_kl            | 0.017670026 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.659      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.225       |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.0326     |
# |    value_loss           | 1.63        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.4        |
# |    ep_rew_mean          | 33          |
# | time/                   |             |
# |    fps                  | 1680        |
# |    iterations           | 74          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.017177919 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.661      |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.203       |
# |    n_updates            | 730         |
# |    policy_gradient_loss | -0.0371     |
# |    value_loss           | 1.24        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.6        |
# |    ep_rew_mean          | 33          |
# | time/                   |             |
# |    fps                  | 1681        |
# |    iterations           | 75          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 307200      |
# | train/                  |             |
# |    approx_kl            | 0.015731364 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.623      |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.276       |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.0341     |
# |    value_loss           | 1.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.4        |
# |    ep_rew_mean          | 33.7        |
# | time/                   |             |
# |    fps                  | 1679        |
# |    iterations           | 76          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.021645695 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.674      |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.178       |
# |    n_updates            | 750         |
# |    policy_gradient_loss | -0.0362     |
# |    value_loss           | 1.3         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37          |
# |    ep_rew_mean          | 33.4        |
# | time/                   |             |
# |    fps                  | 1679        |
# |    iterations           | 77          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 315392      |
# | train/                  |             |
# |    approx_kl            | 0.014724851 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.64       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.297       |
# |    n_updates            | 760         |
# |    policy_gradient_loss | -0.0331     |
# |    value_loss           | 1.64        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.3        |
# |    ep_rew_mean          | 32.2        |
# | time/                   |             |
# |    fps                  | 1680        |
# |    iterations           | 78          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.015970591 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.672      |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.286       |
# |    n_updates            | 770         |
# |    policy_gradient_loss | -0.0342     |
# |    value_loss           | 1.35        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.4        |
# |    ep_rew_mean          | 32.7        |
# | time/                   |             |
# |    fps                  | 1680        |
# |    iterations           | 79          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 323584      |
# | train/                  |             |
# |    approx_kl            | 0.018700194 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.672      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.314       |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.0341     |
# |    value_loss           | 1.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.1        |
# |    ep_rew_mean          | 33.2        |
# | time/                   |             |
# |    fps                  | 1681        |
# |    iterations           | 80          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.015685316 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.668      |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.389       |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.0324     |
# |    value_loss           | 1.32        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 37.4       |
# |    ep_rew_mean          | 33         |
# | time/                   |            |
# |    fps                  | 1681       |
# |    iterations           | 81         |
# |    time_elapsed         | 197        |
# |    total_timesteps      | 331776     |
# | train/                  |            |
# |    approx_kl            | 0.02034216 |
# |    clip_fraction        | 0.169      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.669     |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.291      |
# |    n_updates            | 800        |
# |    policy_gradient_loss | -0.0335    |
# |    value_loss           | 1.64       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.1        |
# |    ep_rew_mean          | 34          |
# | time/                   |             |
# |    fps                  | 1682        |
# |    iterations           | 82          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 335872      |
# | train/                  |             |
# |    approx_kl            | 0.016414601 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.282       |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.0364     |
# |    value_loss           | 1.51        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.1        |
# |    ep_rew_mean          | 32.8        |
# | time/                   |             |
# |    fps                  | 1683        |
# |    iterations           | 83          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 339968      |
# | train/                  |             |
# |    approx_kl            | 0.016426103 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.66       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.228       |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0355     |
# |    value_loss           | 1.53        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38          |
# |    ep_rew_mean          | 33.9        |
# | time/                   |             |
# |    fps                  | 1682        |
# |    iterations           | 84          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.019440558 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.216       |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0375     |
# |    value_loss           | 1.25        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 37.8       |
# |    ep_rew_mean          | 33.6       |
# | time/                   |            |
# |    fps                  | 1677       |
# |    iterations           | 85         |
# |    time_elapsed         | 207        |
# |    total_timesteps      | 348160     |
# | train/                  |            |
# |    approx_kl            | 0.01683278 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.673     |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.34       |
# |    n_updates            | 840        |
# |    policy_gradient_loss | -0.0336    |
# |    value_loss           | 1.46       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.6        |
# |    ep_rew_mean          | 33.7        |
# | time/                   |             |
# |    fps                  | 1677        |
# |    iterations           | 86          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 352256      |
# | train/                  |             |
# |    approx_kl            | 0.018078044 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.675      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.249       |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0382     |
# |    value_loss           | 1.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.1        |
# |    ep_rew_mean          | 33.6        |
# | time/                   |             |
# |    fps                  | 1055        |
# |    iterations           | 87          |
# |    time_elapsed         | 337         |
# |    total_timesteps      | 356352      |
# | train/                  |             |
# |    approx_kl            | 0.014110522 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.648      |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.395       |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0317     |
# |    value_loss           | 1.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.4        |
# |    ep_rew_mean          | 33.6        |
# | time/                   |             |
# |    fps                  | 1036        |
# |    iterations           | 88          |
# |    time_elapsed         | 347         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.016524423 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.651      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.232       |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.037      |
# |    value_loss           | 1.3         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.5        |
# |    ep_rew_mean          | 34          |
# | time/                   |             |
# |    fps                  | 1035        |
# |    iterations           | 89          |
# |    time_elapsed         | 351         |
# |    total_timesteps      | 364544      |
# | train/                  |             |
# |    approx_kl            | 0.017053926 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.658      |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.459       |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0346     |
# |    value_loss           | 1.55        |
# -----------------------------------------

# %%
if training_history.empty:
    print("No training history was loaded.")
else:
    fig, axes = plt.subplots(
        len(TASK_SIZES),
        1,
        figsize=(11, 2.7 * len(TASK_SIZES)),
        sharex=True,
    )
    for ax, n_tasks in zip(axes, TASK_SIZES):
        subset = training_history.loc[
            training_history["tasks"] == n_tasks
        ]
        for ppo_seed, seed_data in subset.groupby("ppo_seed"):
            seed_data = seed_data.sort_values("timestep").copy()
            window = max(10, min(50, len(seed_data) // 10))
            seed_data["smoothed"] = (
                seed_data["episode_return"]
                .rolling(window, min_periods=1)
                .mean()
            )
            ax.plot(
                seed_data["timestep"],
                seed_data["smoothed"],
                linewidth=1.8,
                label=f"seed {ppo_seed}",
            )
        ax.set_ylabel(f"T={n_tasks}")
        ax.grid(alpha=0.25)
        ax.legend(loc="lower right")
    axes[0].set_title(
        "Curvas de entrenamiento PPO — diagnóstico, no resultado final"
    )
    axes[-1].set_xlabel("Pasos de entrenamiento")
    fig.text(
        0.01,
        0.5,
        "Retorno medio móvil",
        rotation=90,
        va="center",
    )
    plt.tight_layout(rect=(0.03, 0, 1, 1))
    plt.show()

# %% [markdown]
# ## 4. Evaluación congelada sobre las 30 instancias
#
# Para cada tamaño:
#
# 1. se construye una de las instancias `1–30`;
# 2. Greedy y PPO reciben el mismo escenario;
# 3. se usa la misma semilla de episodio;
# 4. PPO actúa de forma determinista y no actualiza sus pesos.
#
# Los flujos aleatorios son contrabalanceados por claves de evento. La
# revelación de una tarea y una misma asignación helicóptero–tarea conservan
# su realización aunque otra política haya ejecutado antes una acción distinta.
# Acciones diferentes, naturalmente, generan eventos diferentes.

# %%
PRIORITIES = ("medical", "personnel", "cargo")


def policy_row(
    simulator,
    policy,
    n_tasks,
    instance_seed,
    episode_replicate,
    episode_seed,
    ppo_seed,
    steps,
):
    summary = simulator.summary()
    rewards = {
        record.task_id: record.reward
        for record in simulator.log
        if record.event == "task_completed"
    }
    row = {
        "tasks": int(n_tasks),
        "instance_seed": int(instance_seed),
        "replicate": int(episode_replicate),
        "episode_seed": int(episode_seed),
        "policy": policy,
        "ppo_seed": int(ppo_seed),
        "benefit": float(summary["benefit"]),
        "completed_tasks": int(summary["completed_tasks"]),
        "completion_rate": float(summary["completion_rate"]),
        "relevant_completion_rate": float(
            summary["relevant_completion_rate"]
        ),
        "average_response_time": float(
            summary["average_response_time"]
        ),
        "makespan": float(summary["makespan"]),
        "flight_time": float(summary["flight_time"]),
        "failures": int(summary["failures"]),
        "invalid_actions": int(summary["invalid_actions"]),
        "steps": int(steps),
    }
    for priority in PRIORITIES:
        priority_tasks = [
            task
            for task in simulator.scenario.tasks
            if task.priority_class.value == priority
        ]
        completed = [
            task
            for task in priority_tasks
            if simulator.task_states[task.task_id].status.value
            == "completed"
        ]
        row[f"{priority}_completion_rate"] = (
            len(completed) / len(priority_tasks)
            if priority_tasks
            else np.nan
        )
        row[f"{priority}_benefit"] = sum(
            rewards.get(task.task_id, 0.0)
            for task in priority_tasks
        )
    return row


def run_greedy(scenario, episode_seed, **metadata):
    result, simulator = run_episode(
        scenario,
        GreedyOnlinePolicy(),
        uncertainty=uncertainty,
        seed=episode_seed,
    )
    return (
        policy_row(
            simulator,
            policy="Greedy online",
            ppo_seed=-1,
            steps=result.steps,
            episode_seed=episode_seed,
            **metadata,
        ),
        simulator,
    )


def run_ppo(scenario, model, ppo_seed, episode_seed, **metadata):
    environment = TTAPGymEnv(
        scenario, 
        uncertainty, 
        reward_scale=1.0)
    observation, _ = environment.reset(seed=episode_seed)
    terminated = truncated = False
    steps = 0
    while not (terminated or truncated):
        action, _ = model.predict(
            observation,
            deterministic=True,
            action_masks=environment.action_masks(),
        )
        observation, _, terminated, truncated, _ = environment.step(
            int(action)
        )
        steps += 1
    simulator = environment.simulator
    row = policy_row(
        simulator,
        policy="PPO",
        ppo_seed=ppo_seed,
        steps=steps,
        episode_seed=episode_seed,
        **metadata,
    )
    environment.close()
    return row, simulator

# %%
evaluation_records = []

if RUN_EVALUATION:
    total_cases = (
        len(TASK_SIZES)
        * len(EVAL_INSTANCE_SEEDS)
        * EVAL_REPLICATES
    )
    completed_cases = 0
    for n_tasks in TASK_SIZES:
        task_start = time.perf_counter()
        for instance_seed in EVAL_INSTANCE_SEEDS:
            scenario = build_experiment_a_scenario(
                n_tasks, instance_seed
            )
            for replicate in range(EVAL_REPLICATES):
                episode_seed = (
                    10_000_000
                    + 100_000 * n_tasks
                    + 100 * instance_seed
                    + replicate
                )
                metadata = {
                    "n_tasks": n_tasks,
                    "instance_seed": instance_seed,
                    "episode_replicate": replicate,
                }
                greedy_row, _ = run_greedy(
                    scenario, episode_seed, **metadata
                )
                evaluation_records.append(greedy_row)

                for ppo_seed in PPO_TRAIN_SEEDS:
                    ppo_row, _ = run_ppo(
                        scenario,
                        models[(n_tasks, ppo_seed)],
                        ppo_seed,
                        episode_seed,
                        **metadata,
                    )
                    evaluation_records.append(ppo_row)

                completed_cases += 1

        pd.DataFrame(evaluation_records).to_csv(
            evaluation_path, index=False
        )
        elapsed = time.perf_counter() - task_start
        print(
            f"T={n_tasks} completed; "
            f"{completed_cases}/{total_cases} cases; "
            f"{elapsed:.1f} s"
        )
else:
    if not evaluation_path.exists():
        raise FileNotFoundError(evaluation_path)
    evaluation_records = pd.read_csv(evaluation_path).to_dict("records")

evaluation = pd.DataFrame(evaluation_records)
assert evaluation["invalid_actions"].sum() == 0
print("Evaluation rows:", len(evaluation))
print("Saved:", evaluation_path)
evaluation.head()

# %% [markdown]
# ## 5. Resultado principal: generalización fuera de muestra
#
# Primero se promedian las realizaciones estocásticas dentro de cada
# instancia. Para PPO también se promedian las semillas de entrenamiento.
# Así, las 30 instancias —no cientos de episodios artificialmente tratados
# como independientes— son la unidad principal de comparación.

# %%
METRICS = [
    "benefit",
    "completed_tasks",
    "completion_rate",
    "relevant_completion_rate",
    "average_response_time",
    "makespan",
    "flight_time",
    "medical_completion_rate",
    "personnel_completion_rate",
    "cargo_completion_rate",
]

greedy_instance = (
    evaluation.loc[evaluation["policy"] == "Greedy online"]
    .groupby(["tasks", "instance_seed"], as_index=False)[METRICS]
    .mean()
)
ppo_model_instance = (
    evaluation.loc[evaluation["policy"] == "PPO"]
    .groupby(
        ["tasks", "instance_seed", "ppo_seed"],
        as_index=False,
    )[METRICS]
    .mean()
)
ppo_instance = (
    ppo_model_instance
    .groupby(["tasks", "instance_seed"], as_index=False)[METRICS]
    .mean()
)

greedy_instance["policy"] = "Greedy online"
ppo_instance["policy"] = "PPO"
policy_instance = pd.concat(
    [greedy_instance, ppo_instance],
    ignore_index=True,
)

summary_rows = []
for (n_tasks, policy), group in policy_instance.groupby(
    ["tasks", "policy"]
):
    row = {
        "Tasks": n_tasks,
        "Policy": policy,
        "Instances": group["instance_seed"].nunique(),
    }
    for metric in (
        "benefit",
        "completed_tasks",
        "relevant_completion_rate",
        "average_response_time",
        "flight_time",
    ):
        values = group[metric].astype(float)
        half = 1.96 * values.std(ddof=1) / np.sqrt(len(values))
        row[f"{metric}_mean"] = values.mean()
        row[f"{metric}_ci95"] = half
    summary_rows.append(row)

scaling_summary = pd.DataFrame(summary_rows).sort_values(
    ["Tasks", "Policy"]
)
scaling_summary

# %%
policy_order = ["Greedy online", "PPO"]
colors = {"Greedy online": "#F28E2B", "PPO": "#4E79A7"}

fig, ax = plt.subplots(figsize=(10, 5.2))
for policy in policy_order:
    data = scaling_summary.loc[
        scaling_summary["Policy"] == policy
    ].sort_values("Tasks")
    ax.errorbar(
        data["Tasks"],
        data["benefit_mean"],
        yerr=data["benefit_ci95"],
        marker="o",
        markersize=6,
        linewidth=2.2,
        capsize=4,
        color=colors[policy],
        label=policy,
    )
ax.set(
    title="Resultado principal fuera de muestra",
    xlabel="Número de tareas",
    ylabel="Beneficio normalizado medio (IC 95%)",
    xticks=TASK_SIZES,
)
ax.grid(alpha=0.25)
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Diferencia pareada PPO − Greedy
#
# Para cada una de las 30 instancias se calcula:
#
# \[
# \Delta_s=B_s^{PPO}-B_s^{Greedy}.
# \]
#
# - \(\Delta_s>0\): PPO obtiene más beneficio.
# - \(\Delta_s=0\): empate.
# - \(\Delta_s<0\): Greedy obtiene más beneficio.
#
# El intervalo se calcula con *bootstrap* sobre las 30 diferencias de
# instancia. Esto responde directamente si la ventaja se mantiene al cambiar
# la carga de tareas.

# %%
paired = ppo_instance.merge(
    greedy_instance,
    on=["tasks", "instance_seed"],
    suffixes=("_ppo", "_greedy"),
)
paired["delta_benefit"] = (
    paired["benefit_ppo"] - paired["benefit_greedy"]
)


def bootstrap_mean_ci(values, seed, n_boot=5000):
    values = np.asarray(values, dtype=float)
    rng = np.random.default_rng(seed)
    samples = rng.choice(
        values,
        size=(n_boot, len(values)),
        replace=True,
    ).mean(axis=1)
    return np.quantile(samples, [0.025, 0.975])


paired_rows = []
for n_tasks, group in paired.groupby("tasks"):
    delta = group["delta_benefit"].to_numpy()
    low, high = bootstrap_mean_ci(delta, 218 + int(n_tasks))
    paired_rows.append(
        {
            "Tasks": int(n_tasks),
            "Mean PPO-Greedy": delta.mean(),
            "CI95 low": low,
            "CI95 high": high,
            "PPO wins": int((delta > 1e-12).sum()),
            "Ties": int(np.isclose(delta, 0.0, atol=1e-12).sum()),
            "Greedy wins": int((delta < -1e-12).sum()),
            "PPO win rate": float((delta > 1e-12).mean()),
        }
    )
paired_summary = pd.DataFrame(paired_rows)
paired_summary

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4.8))

center = paired_summary["Mean PPO-Greedy"]
lower_error = center - paired_summary["CI95 low"]
upper_error = paired_summary["CI95 high"] - center
axes[0].errorbar(
    paired_summary["Tasks"],
    center,
    yerr=np.vstack([lower_error, upper_error]),
    marker="o",
    linewidth=2.2,
    capsize=4,
    color="#4E79A7",
)
axes[0].axhline(0, color="black", linestyle="--", linewidth=1)
axes[0].set(
    title="Ventaja media pareada",
    xlabel="Número de tareas",
    ylabel=r"$\Delta$ beneficio: PPO − Greedy (IC 95%)",
    xticks=TASK_SIZES,
)
axes[0].grid(alpha=0.25)

axes[1].bar(
    paired_summary["Tasks"],
    100 * paired_summary["PPO win rate"],
    width=6,
    color="#4E79A7",
    alpha=0.75,
)
axes[1].axhline(50, color="black", linestyle="--", linewidth=1)
axes[1].set(
    title="Frecuencia de victoria de PPO",
    xlabel="Número de tareas",
    ylabel="Instancias con PPO > Greedy (%)",
    xticks=TASK_SIZES,
    ylim=(0, 100),
)
axes[1].grid(axis="y", alpha=0.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. ¿De dónde viene la diferencia?
#
# El beneficio es la métrica principal, pero no basta para explicar la
# conducta. Los paneles siguientes separan:
#
# - tareas completadas;
# - tareas relevantes completadas;
# - tiempo medio de respuesta;
# - tiempo total de vuelo.
#
# Esto permite distinguir una mejora humanitaria de un simple aumento de
# actividad operacional.

# %%
dashboard = [
    ("completed_tasks", "Tareas completadas", True),
    (
        "relevant_completion_rate",
        "Relevant completion rate",
        True,
    ),
    (
        "average_response_time",
        "Tiempo medio de respuesta",
        False,
    ),
    ("flight_time", "Tiempo total de vuelo", False),
]

fig, axes = plt.subplots(2, 2, figsize=(12, 8))
for ax, (metric, title, higher_is_better) in zip(
    axes.flat, dashboard
):
    for policy in policy_order:
        group = policy_instance.loc[
            policy_instance["policy"] == policy
        ]
        summary = (
            group.groupby("tasks")[metric]
            .agg(["mean", "std", "count"])
            .reindex(TASK_SIZES)
        )
        ci = 1.96 * summary["std"] / np.sqrt(summary["count"])
        ax.errorbar(
            TASK_SIZES,
            summary["mean"],
            yerr=ci,
            marker="o",
            capsize=3,
            linewidth=1.9,
            color=colors[policy],
            label=policy,
        )
    ax.set_title(title)
    ax.set_xticks(TASK_SIZES)
    ax.grid(alpha=0.25)
    direction = "↑ mejor" if higher_is_better else "↓ mejor"
    ax.set_xlabel(direction)
axes[0, 0].legend()
plt.tight_layout()
plt.show()

# %%
priority_metrics = [
    ("medical_completion_rate", "Medical"),
    ("personnel_completion_rate", "Personnel"),
    ("cargo_completion_rate", "Cargo"),
]
fig, axes = plt.subplots(1, 3, figsize=(14, 4.2), sharey=True)
for ax, (metric, label) in zip(axes, priority_metrics):
    for policy in policy_order:
        group = policy_instance.loc[
            policy_instance["policy"] == policy
        ]
        summary = (
            group.groupby("tasks")[metric]
            .agg(["mean", "std", "count"])
            .reindex(TASK_SIZES)
        )
        ci = 1.96 * summary["std"] / np.sqrt(summary["count"])
        ax.errorbar(
            TASK_SIZES,
            summary["mean"],
            yerr=ci,
            marker="o",
            capsize=3,
            linewidth=1.8,
            color=colors[policy],
            label=policy,
        )
    ax.set_title(label)
    ax.set_xlabel("Número de tareas")
    ax.set_xticks(TASK_SIZES)
    ax.grid(alpha=0.25)
axes[0].set_ylabel("Completion rate por prioridad")
axes[0].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Estabilidad entre semillas PPO
#
# Un solo entrenamiento puede ser afortunado o desfavorable. En modo formal,
# la tabla muestra el beneficio fuera de muestra de cada semilla PPO.
# Resultados similares entre columnas indican estabilidad. Diferencias grandes
# obligan a aumentar semillas o revisar hiperparámetros.

# %%
ppo_seed_summary = (
    ppo_model_instance
    .groupby(["tasks", "ppo_seed"], as_index=False)
    .agg(
        benefit_mean=("benefit", "mean"),
        benefit_sd=("benefit", "std"),
        completed_mean=("completed_tasks", "mean"),
        response_mean=("average_response_time", "mean"),
    )
)
stability_table = ppo_seed_summary.pivot(
    index="tasks",
    columns="ppo_seed",
    values="benefit_mean",
)
stability_table

# %%
if training_history.empty:
    print("Training history unavailable.")
else:
    training_tail = (
        training_history.sort_values("timestep")
        .groupby(["tasks", "ppo_seed"], as_index=False)
        .tail(100)
        .groupby(["tasks", "ppo_seed"], as_index=False)
        .agg(training_last100=("episode_return", "mean"))
    )
    generalization = ppo_seed_summary.merge(
        training_tail,
        on=["tasks", "ppo_seed"],
        how="left",
    )
    generalization["evaluation_minus_training"] = (
        generalization["benefit_mean"]
        - generalization["training_last100"]
    )
    display(generalization)

# %% [markdown]
# ## 9. Tres casos operacionales
#
# Para el tamaño seleccionado se inspeccionan:
#
# - la instancia donde PPO gana más;
# - una instancia cercana a la diferencia mediana;
# - la instancia donde Greedy gana más.
#
# Las curvas muestran **cuándo** se captura el beneficio. Luego se listan las
# primeras operaciones para identificar dónde divergen las decisiones.

# %%
DETAIL_TASKS = 60
DETAIL_PPO_SEED = PPO_TRAIN_SEEDS[0]
DETAIL_REPLICATE = 0

detail_model_instances = ppo_model_instance.loc[
    (ppo_model_instance["tasks"] == DETAIL_TASKS)
    & (ppo_model_instance["ppo_seed"] == DETAIL_PPO_SEED)
].merge(
    greedy_instance.loc[greedy_instance["tasks"] == DETAIL_TASKS],
    on=["tasks", "instance_seed"],
    suffixes=("_ppo", "_greedy"),
)
detail_model_instances["delta"] = (
    detail_model_instances["benefit_ppo"]
    - detail_model_instances["benefit_greedy"]
)
median_delta = detail_model_instances["delta"].median()
selected_instances = {
    "Mayor ventaja PPO": int(
        detail_model_instances.loc[
            detail_model_instances["delta"].idxmax(),
            "instance_seed",
        ]
    ),
    "Caso mediano": int(
        detail_model_instances.loc[
            (
                detail_model_instances["delta"] - median_delta
            ).abs().idxmin(),
            "instance_seed",
        ]
    ),
    "Mayor ventaja Greedy": int(
        detail_model_instances.loc[
            detail_model_instances["delta"].idxmin(),
            "instance_seed",
        ]
    ),
}
selected_instances

# %%
detailed_runs = {}
detailed_rows = []
for case_name, instance_seed in selected_instances.items():
    scenario = build_experiment_a_scenario(
        DETAIL_TASKS, instance_seed
    )
    episode_seed = (
        10_000_000
        + 100_000 * DETAIL_TASKS
        + 100 * instance_seed
        + DETAIL_REPLICATE
    )
    metadata = {
        "n_tasks": DETAIL_TASKS,
        "instance_seed": instance_seed,
        "episode_replicate": DETAIL_REPLICATE,
    }
    greedy_row, greedy_simulator = run_greedy(
        scenario, episode_seed, **metadata
    )
    ppo_row, ppo_simulator = run_ppo(
        scenario,
        models[(DETAIL_TASKS, DETAIL_PPO_SEED)],
        DETAIL_PPO_SEED,
        episode_seed,
        **metadata,
    )
    detailed_runs[case_name] = {
        "Greedy online": greedy_simulator,
        "PPO": ppo_simulator,
    }
    detailed_rows.extend(
        [
            {"case": case_name, **greedy_row},
            {"case": case_name, **ppo_row},
        ]
    )

pd.DataFrame(detailed_rows)[
    [
        "case",
        "instance_seed",
        "policy",
        "benefit",
        "completed_tasks",
        "relevant_completion_rate",
        "average_response_time",
        "flight_time",
    ]
]

# %%
def cumulative_trace(simulator):
    times = [0.0]
    values = [0.0]
    cumulative = 0.0
    for record in sorted(simulator.log, key=lambda item: item.time):
        if record.event == "task_completed":
            cumulative += record.reward
            times.append(record.time)
            values.append(cumulative)
    return np.asarray(times), np.asarray(values)


fig, axes = plt.subplots(1, 3, figsize=(15, 4.3), sharey=True)
for ax, (case_name, simulations) in zip(
    axes, detailed_runs.items()
):
    for policy in policy_order:
        times, values = cumulative_trace(simulations[policy])
        ax.step(
            times,
            values,
            where="post",
            linewidth=2,
            color=colors[policy],
            label=policy,
        )
    ax.set_title(case_name)
    ax.set_xlabel("Tiempo de misión")
    ax.grid(alpha=0.25)
axes[0].set_ylabel("Beneficio acumulado")
axes[0].legend()
plt.tight_layout()
plt.show()

# %%
def operation_sequence(simulator, policy, case_name):
    rows = []
    for record in sorted(
        simulator.log,
        key=lambda item: (
            item.time,
            item.helicopter_id or "",
            item.task_id or "",
        ),
    ):
        if record.event not in (
            "task_dispatched",
            "return_dispatched",
            "dispatch_failure",
        ):
            continue
        rows.append(
            {
                "case": case_name,
                "policy": policy,
                "time": record.time,
                "event": record.event,
                "helicopter": record.helicopter_id,
                "task": record.task_id,
                "node": record.node_id,
            }
        )
    return pd.DataFrame(rows)


operation_tables = []
for case_name, simulations in detailed_runs.items():
    for policy in policy_order:
        table = operation_sequence(
            simulations[policy], policy, case_name
        )
        table["decision_number"] = np.arange(1, len(table) + 1)
        operation_tables.append(table)

operations = pd.concat(operation_tables, ignore_index=True)
print("Primeras 15 operaciones de cada política y caso")
operations.groupby(["case", "policy"], sort=False).head(15)

# %% [markdown]
# ## 10. Criterio de lectura final
#
# PPO aporta evidencia útil solo si se cumplen simultáneamente estas condiciones:
#
# 1. la curva de entrenamiento no colapsa;
# 2. la política congelada mejora fuera de muestra;
# 3. el IC 95% de \(\Delta\) no depende de una única instancia;
# 4. el resultado es razonablemente estable entre semillas PPO;
# 5. la ventaja puede explicarse mediante prioridad, oportunidad o cobertura;
# 6. el costo operacional adicional, si existe, queda cuantificado.
#
# Si PPO solo muestra una curva ascendente, todavía no existe una conclusión
# comparativa. Si gana fuera de muestra pero solo con una semilla, la evidencia
# sigue siendo exploratoria. El modo formal está diseñado para resolver ambos
# problemas.

# %%
print("Final validation")
print("----------------")
print("Task sizes:", sorted(evaluation["tasks"].unique()))
print(
    "Evaluation instances per size:",
    evaluation.groupby("tasks")["instance_seed"].nunique().to_dict(),
)
print("Policies:", sorted(evaluation["policy"].unique()))
print("PPO seeds:", sorted(
    evaluation.loc[evaluation["policy"] == "PPO", "ppo_seed"]
    .unique()
    .tolist()
))
print("Invalid actions:", int(evaluation["invalid_actions"].sum()))
print("Evaluation CSV:", evaluation_path)
print("Model directory:", model_dir)
