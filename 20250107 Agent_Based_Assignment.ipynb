# %% [markdown]
# # A dynamic task assignment model for aviation emergency rescue based on multi-agent reinforcement learning

# %% [markdown]
# ## Pseudocódigo del Algoritmo Greedy
#
# ### Descripción
# El algoritmo busca $Z = \max \left( \sum_{t=0}^{T} r_t \right)$, dado lo siguiente:
#
# $
# r_t = f \cdot v_t \cdot \left(
# \sum_{\text{task}_i \in \text{Task}}
# \sum_{\text{node}_j \in \text{Node}}
# \frac{D_{i,j,t}}{|D_{i,j,t}|}
# \right)
# $
#
# ### Variables
# - $ N $: conjunto de nodos (ubicaciones de rescate).
# - $ T $: conjunto de tareas.
# - $ H $: conjunto de helicópteros.
# - $t_{\text{current}}$: tiempo actual de la simulación.
# - $ f(t) $: satisfacción temporal, definida como:
#   $
#   f(t^*) =
#   \begin{cases}
#     1 & \text{si } t^* \leq t_1, \\
#     0.5 \cdot \frac{t_2 - t^*}{t_2 - t_1} & \text{si } t_1 < t^* \leq t_2, \\
#     0.5 \cdot \frac{t^* - t_2}{t_{\text{max}} - t_2} & \text{si } t_2 < t^* \leq t_{\text{max}}, \\
#     0 & \text{si } t^* > t_{\text{max}}.
#   \end{cases}
#   $
# - $ v_t $: relación de tareas completadas respecto al total:
#   $
#   v_t = \frac{1}{\text{total\_tasks}}
#   $
# - $ D_{i,j,t} $: variable de decisión, indicando si la tarea $ i $ se asigna al nodo $ j $ en el tiempo $ t $.
#
# ### Pseudocódigo
# 1. **Inicializar** los nodos $ N $, tareas $ T $, y helicópteros $ H $.
# 2. Calcular $ \text{total\_tasks} = |T| $.
#
# 3. Para cada helicóptero $ h \in H $:
#     $ n_{\text{current}} = n_{\text{base}} $ y $ t_{\text{current}} = 0 $.
#
# 4. **While** $ t_{\text{current}} < T_{\text{total}} $:
#     - Para cada tarea $ t_i \in T $:
#         - **If** $ t_i $ no está completada:
#             - Calcular:
#               - Distancia:
#                 $
#                 d = \text{distancia}(n_{\text{current}}, n_{\text{t_i}})
#                 $
#               - Tiempo de viaje:
#                 $
#                 t_{\text{travel}} = \frac{d}{\text{speed}_h}
#                 $
#               - Tiempo de finalización:
#                 $
#                 t_{\text{completion}} = t_{\text{current}} + t_{\text{travel}}
#                 $
#             - Evaluar si el helicóptero $ h $ puede completar la tarea $ t_i $ bajo las restricciones (capacidad, tiempos).
#             - Calcular el beneficio:
#                 $
#                 r_{\text{t}} = f(t_{\text{completion}}) \cdot v_t
#                 $
#     - Seleccionar la tarea $ t_i $ con el mayor beneficio.
#     - Actualizar:
#         - $ \text{current\_node} $ al nodo de $ t_i $.
#         - Marcar $ t_i $ como completada.
#         - Incrementar $ t_{\text{current}} $ por $ t_{\text{travel}} $.
#
# 5. **Resultados finales**:
#     - Número de tareas completadas:
#       $
#       \sum_{i} D_{i,j,t}
#       $
#     - Beneficio total acumulado:
#       $
#       \text{Total Benefit} = \sum_{\text{tasks completed}} f(t^*) \cdot v_t
#       $
#
# 6. **Fin del algoritmo**.

# %%
import random
import math
import matplotlib.pyplot as plt

class Node:
    """Represents a node (location) in the rescue graph."""
    def __init__(self, name, x, y):
        self.name = name
        self.x = x  # X-coordinate
        self.y = y  # Y-coordinate
        self.tasks = []  # Tasks at this node

    def add_task(self, task):
        """Add a task to this node."""
        self.tasks.append(task)

    def distance_to(self, other_node):
        """Calculate the distance to another node."""
        return math.sqrt((self.x - other_node.x)**2 + (self.y - other_node.y)**2)

class Task:
    """Represents a task at a node."""
    def __init__(self, task_id, visual_search, material_transport, medical_assistance, personnel_transfer, optimal_time, effective_time, ineffective_time):
        self.task_id = task_id  # Unique ID for the task
        self.visual_search = visual_search  # True/False if visual search is needed
        self.material_transport = material_transport  # Material weight required (kg)
        self.medical_assistance = medical_assistance  # Number of patients needing assistance
        self.personnel_transfer = personnel_transfer  # Number of personnel to transfer
        self.optimal_time = optimal_time  # Optimal rescue time for maximum benefit
        self.effective_time = effective_time  # Effective rescue time for reduced benefit
        self.ineffective_time = ineffective_time  # Time after which no benefit is awarded
        self.is_completed = False  # Track if task is completed
        self.completion_time = None  # Time when the task was completed

    def calculate_benefit(self, completion_time, total_tasks):
        """
        Calculate the benefit of completing a task.
        completion_time: Time at which the task is completed.
        total_tasks: Total number of tasks in the system (used to calculate v_t).
        """
        # Calculate time satisfaction (f)
        if completion_time <= self.optimal_time:
            f = 1
        elif completion_time <= self.effective_time:
            f = 0.5 * ((self.effective_time - completion_time) / (self.effective_time - self.optimal_time))
        elif completion_time <= self.ineffective_time:
            f = 0.5 * ((completion_time - self.effective_time) / (self.ineffective_time - self.effective_time))
        else:
            f = 0

        # Calculate v_t (task completion ratio)
        v_t = 1 / total_tasks  # Incremental contribution of completing one task
        return f * v_t


class Helicopter:
    """Represents a helicopter in the rescue fleet."""
    def __init__(self, helicopter_id, hovering, visual_search_capability, load_capacity, medical_capacity, passenger_limit, range_km, speed_kmh, position):
        self.helicopter_id = helicopter_id  # Unique ID
        self.hovering = hovering  # Whether it can hover (True/False)
        self.visual_search_capability = visual_search_capability  # True/False if visual search is possible
        self.load_capacity = load_capacity  # Maximum load in kg
        self.medical_capacity = medical_capacity  # Maximum medical assistance capacity
        self.passenger_limit = passenger_limit  # Maximum passengers
        self.range_km = range_km  # Maximum range in km
        self.speed_kmh = speed_kmh  # Speed in km/h
        self.position = position  # Current node (Node object)

    def can_complete_task(self, task):
        """Check if the helicopter can complete a given task."""
        return (
            (not task.visual_search or self.visual_search_capability) and
            self.load_capacity >= task.material_transport and
            self.medical_capacity >= task.medical_assistance and
            self.passenger_limit >= task.personnel_transfer
        )

    def complete_task(self, task, completion_time, total_tasks):
        """Complete a task if resources are sufficient and calculate benefit."""
        if self.can_complete_task(task):
            self.load_capacity -= task.material_transport
            self.medical_capacity -= task.medical_assistance
            self.passenger_limit -= task.personnel_transfer
            task.is_completed = True
            task.completion_time = completion_time
            # Pass total_tasks to calculate_benefit
            return task.calculate_benefit(completion_time, total_tasks)
        return 0

def initialize_graph():
    """Initialize the rescue graph with nodes, tasks, and helicopters."""
    # Define nodes
    central_node = Node("Central Base", 0, 0)  # Centralized base
    nodes = [
        central_node,
        Node("Node A", 10, 5),
        Node("Node B", 20, 15),
        Node("Node C", 30, 10),
        Node("Node D", 40, 20)
    ]

    # Add tasks to nodes
    tasks = [
        Task(task_id=1, visual_search=True, material_transport=200, medical_assistance=2, personnel_transfer=1, optimal_time=20, effective_time=40, ineffective_time=60),
        Task(task_id=2, visual_search=False, material_transport=300, medical_assistance=1, personnel_transfer=2, optimal_time=15, effective_time=30, ineffective_time=50),
        Task(task_id=3, visual_search=True, material_transport=100, medical_assistance=3, personnel_transfer=0, optimal_time=10, effective_time=25, ineffective_time=40),
        Task(task_id=4, visual_search=False, material_transport=200, medical_assistance=0, personnel_transfer=3, optimal_time=30, effective_time=50, ineffective_time=70),
        Task(task_id=5, visual_search=True, material_transport=150, medical_assistance=1, personnel_transfer=1, optimal_time=25, effective_time=45, ineffective_time=60),
        Task(task_id=6, visual_search=True, material_transport=100, medical_assistance=3, personnel_transfer=0, optimal_time=10, effective_time=25, ineffective_time=120),
        Task(task_id=7, visual_search=False, material_transport=400, medical_assistance=0, personnel_transfer=3, optimal_time=30, effective_time=50, ineffective_time=90),
        Task(task_id=8, visual_search=True, material_transport=150, medical_assistance=1, personnel_transfer=1, optimal_time=25, effective_time=45, ineffective_time=100),
        Task(task_id=9, visual_search=True, material_transport=200, medical_assistance=2, personnel_transfer=1, optimal_time=20, effective_time=40, ineffective_time=60),
        Task(task_id=10, visual_search=False, material_transport=300, medical_assistance=1, personnel_transfer=2, optimal_time=15, effective_time=30, ineffective_time=50),
        Task(task_id=11, visual_search=True, material_transport=100, medical_assistance=3, personnel_transfer=0, optimal_time=10, effective_time=25, ineffective_time=40),
        Task(task_id=12, visual_search=False, material_transport=200, medical_assistance=0, personnel_transfer=3, optimal_time=30, effective_time=50, ineffective_time=70),
        Task(task_id=13, visual_search=True, material_transport=150, medical_assistance=1, personnel_transfer=1, optimal_time=25, effective_time=45, ineffective_time=60),
        Task(task_id=14, visual_search=True, material_transport=100, medical_assistance=3, personnel_transfer=0, optimal_time=10, effective_time=25, ineffective_time=120),
        Task(task_id=15, visual_search=False, material_transport=400, medical_assistance=0, personnel_transfer=3, optimal_time=30, effective_time=50, ineffective_time=90),
        Task(task_id=16, visual_search=True, material_transport=150, medical_assistance=1, personnel_transfer=1, optimal_time=25, effective_time=45, ineffective_time=100),
        Task(task_id=17, visual_search=True, material_transport=150, medical_assistance=1, personnel_transfer=1, optimal_time=25, effective_time=45, ineffective_time=60),
        Task(task_id=18, visual_search=True, material_transport=100, medical_assistance=3, personnel_transfer=0, optimal_time=10, effective_time=25, ineffective_time=120),
        Task(task_id=19, visual_search=False, material_transport=400, medical_assistance=0, personnel_transfer=3, optimal_time=30, effective_time=50, ineffective_time=90),
        Task(task_id=20, visual_search=True, material_transport=150, medical_assistance=1, personnel_transfer=1, optimal_time=25, effective_time=45, ineffective_time=100),
    ]
    nodes[1].add_task(tasks[0])
    nodes[1].add_task(tasks[1])
    nodes[1].add_task(tasks[8])
    nodes[1].add_task(tasks[9])
    nodes[2].add_task(tasks[2])
    nodes[2].add_task(tasks[7])
    nodes[2].add_task(tasks[6])
    nodes[2].add_task(tasks[10])
    nodes[2].add_task(tasks[11])
    nodes[2].add_task(tasks[12])
    nodes[2].add_task(tasks[13])
    nodes[3].add_task(tasks[4])
    nodes[3].add_task(tasks[5])
    nodes[3].add_task(tasks[14])
    nodes[3].add_task(tasks[15])
    nodes[4].add_task(tasks[3])
    nodes[4].add_task(tasks[16])
    nodes[4].add_task(tasks[17])
    nodes[4].add_task(tasks[18])
    nodes[4].add_task(tasks[19])

    # Define helicopters stationed at the central base
    helicopters = [
        Helicopter(1, hovering=True, visual_search_capability=True, load_capacity=500, medical_capacity=3, passenger_limit=3, range_km=500, speed_kmh=150, position=central_node),
        Helicopter(2, hovering=True, visual_search_capability=False, load_capacity=500, medical_capacity=3, passenger_limit=3, range_km=500, speed_kmh=150, position=central_node),
        Helicopter(3, hovering=True, visual_search_capability=True, load_capacity=500, medical_capacity=3, passenger_limit=3, range_km=500, speed_kmh=150, position=central_node),
        Helicopter(4, hovering=True, visual_search_capability=False, load_capacity=500, medical_capacity=3, passenger_limit=3, range_km=500, speed_kmh=150, position=central_node),
    ]

    return nodes, helicopters

def assign_task_with_vt(helicopter, nodes, current_time, total_tasks):
    """
    Assign a task to the helicopter considering the new benefit function.
    """
    best_task = None
    best_task_node = None
    max_benefit = 0

    for node in nodes:
        for task in node.tasks:
            if not task.is_completed:
                # Calculate travel time to the task
                distance = helicopter.position.distance_to(node)
                travel_time = distance / helicopter.speed_kmh * 60  # Tiempo en minutos
                completion_time = current_time + travel_time

                # Check if the helicopter can complete the task
                if helicopter.can_complete_task(task):
                    # Calculate adjusted benefit (f * v_t)
                    benefit = task.calculate_benefit(completion_time, total_tasks)
                    if benefit > max_benefit:
                        max_benefit = benefit
                        best_task = task
                        best_task_node = node

    if best_task:
        # Move the helicopter to the task's node
        distance = helicopter.position.distance_to(best_task_node)
        travel_time = distance / helicopter.speed_kmh * 60  # Tiempo en minutos
        helicopter.position = best_task_node
        print(
            f"Assigned: Helicopter {helicopter.helicopter_id} to Task {best_task.task_id} at {best_task_node.name}. Flight time: {travel_time:.1f} minutes."
        )
        return best_task, travel_time
    else:
        print(f"No suitable tasks for Helicopter {helicopter.helicopter_id}.")
        return None, 0

def simulate_rescue_with_vt(nodes, helicopters, total_time):
    """
    Simulate the rescue operation with the adjusted benefit function (f * v_t).
    """
    current_time = 0
    total_tasks = sum(len(node.tasks) for node in nodes)  # Total number of tasks
    completed_tasks = 0  # Track completed tasks
    total_benefit = 0
    
    # Data for plotting
    completion_times = []
    individual_benefits = []

    while current_time < total_time:
        for helicopter in helicopters:
            # Assign a task to the helicopter
            task, travel_time = assign_task_with_vt(helicopter, nodes, current_time, total_tasks)

            if task:
                # Update time and track task completion
                current_time += travel_time
                task_completion_time = current_time

                # Complete the task and calculate benefit
                benefit = helicopter.complete_task(task, task_completion_time, total_tasks)
                total_benefit += benefit
                completed_tasks += 1
                
                # Store data for plotting
                completion_times.append(task_completion_time)
                individual_benefits.append(benefit)

                print(
                    f"Task {task.task_id} completed by Helicopter {helicopter.helicopter_id} at time {task_completion_time:.1f} minutes. Benefit: {benefit:.4f}"
                )

        # Increment the simulation time (if no tasks are assigned)
        current_time += 1

    print(f"\nSimulation completed. \nTotal tasks completed: {completed_tasks}/{total_tasks}. \nTotal benefit: {total_benefit:.4f}")
    
    # Calculate cumulative benefits
    cumulative_benefits = []
    total = 0
    for b in individual_benefits:
        total += b
        cumulative_benefits.append(total)
        
    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(completion_times, cumulative_benefits, marker="o", linestyle="-", label="Cumulative Benefit")
    plt.title("Cumulative Benefit Over Time - Greedy Algorithm", fontsize=14)
    plt.xlabel("Time (minutes)", fontsize=12)
    plt.ylabel("Cumulative Benefit", fontsize=12)
    plt.ylim(0, 0.6)
    plt.grid(True, linestyle="--", alpha=0.7)
    plt.legend(fontsize=12)
    plt.tight_layout()
    plt.show()

# Initialize the rescue graph
nodes, helicopters = initialize_graph()

# Run the simulation
simulate_rescue_with_vt(nodes, helicopters, total_time=38)
# Out:
# Assigned: Helicopter 1 to Task 1 at Node A. Flight time: 4.5 minutes.
# Task 1 completed by Helicopter 1 at time 4.5 minutes. Benefit: 0.0500
# Assigned: Helicopter 2 to Task 2 at Node A. Flight time: 4.5 minutes.
# Task 2 completed by Helicopter 2 at time 8.9 minutes. Benefit: 0.0500
# Assigned: Helicopter 3 to Task 9 at Node A. Flight time: 4.5 minutes.
# Task 9 completed by Helicopter 3 at time 13.4 minutes. Benefit: 0.0500
# Assigned: Helicopter 4 to Task 7 at Node B. Flight time: 10.0 minutes.
# Task 7 completed by Helicopter 4 at time 23.4 minutes. Benefit: 0.0500
# Assigned: Helicopter 1 to Task 8 at Node B. Flight time: 5.7 minutes.
# Task 8 completed by Helicopter 1 at time 30.1 minutes. Benefit: 0.0187
# No suitable tasks for Helicopter 2.
# Assigned: Helicopter 3 to Task 13 at Node B. Flight time: 5.7 minutes.
# Task 13 completed by Helicopter 3 at time 35.7 minutes. Benefit: 0.0116
# No suitable tasks for Helicopter 4.
# No suitable tasks for Helicopter 1.
# No suitable tasks for Helicopter 2.
# No suitable tasks for Helicopter 3.
# No suitable tasks for Helicopter 4.
# No suitable tasks for Helicopter 1.
# No suitable tasks for Helicopter 2.
# No suitable tasks for Helicopter 3.
# No suitable tasks for Helicopter 4.
#
# Simulation completed.
# Total tasks completed: 6/20.
# Total benefit: 0.2302

# %%
import random
import math
import matplotlib.pyplot as plt

class Node:
    """Represents a node (location) in the rescue graph."""
    def __init__(self, name, x, y):
        self.name = name
        self.x = x  # X-coordinate
        self.y = y  # Y-coordinate
        self.tasks = []  # Tasks at this node

    def add_task(self, task):
        """Add a task to this node."""
        self.tasks.append(task)

    def distance_to(self, other_node):
        """Calculate the distance to another node."""
        return math.sqrt((self.x - other_node.x)**2 + (self.y - other_node.y)**2)

class Task:
    """Represents a task at a node."""
    def __init__(self, task_id, visual_search, material_transport, medical_assistance, personnel_transfer, optimal_time, effective_time, ineffective_time):
        self.task_id = task_id  # Unique ID for the task
        self.visual_search = visual_search  # True/False if visual search is needed
        self.material_transport = material_transport  # Material weight required (kg)
        self.medical_assistance = medical_assistance  # Number of patients needing assistance
        self.personnel_transfer = personnel_transfer  # Number of personnel to transfer
        self.optimal_time = optimal_time  # Optimal rescue time for maximum benefit
        self.effective_time = effective_time  # Effective rescue time for reduced benefit
        self.ineffective_time = ineffective_time  # Time after which no benefit is awarded
        self.is_completed = False  # Track if task is completed
        self.completion_time = None  # Time when the task was completed

    def calculate_benefit(self, completion_time, total_tasks):
        """
        Calculate the benefit of completing a task.
        completion_time: Time at which the task is completed.
        total_tasks: Total number of tasks in the system (used to calculate v_t).
        """
        # Calculate time satisfaction (f)
        if completion_time <= self.optimal_time:
            f = 1
        elif completion_time <= self.effective_time:
            f = 0.5 * ((self.effective_time - completion_time) / (self.effective_time - self.optimal_time))
        elif completion_time <= self.ineffective_time:
            f = 0.5 * ((completion_time - self.effective_time) / (self.ineffective_time - self.effective_time))
        else:
            f = 0

        # Calculate v_t (task completion ratio)
        v_t = 1 / total_tasks  # Incremental contribution of completing one task
        return f * v_t


class Helicopter:
    """Represents a helicopter in the rescue fleet."""
    def __init__(self, helicopter_id, hovering, visual_search_capability, load_capacity, medical_capacity, passenger_limit, range_km, speed_kmh, position):
        self.helicopter_id = helicopter_id  # Unique ID
        self.hovering = hovering  # Whether it can hover (True/False)
        self.visual_search_capability = visual_search_capability  # True/False if visual search is possible
        self.load_capacity = load_capacity  # Maximum load in kg
        self.medical_capacity = medical_capacity  # Maximum medical assistance capacity
        self.passenger_limit = passenger_limit  # Maximum passengers
        self.range_km = range_km  # Maximum range in km
        self.speed_kmh = speed_kmh  # Speed in km/h
        self.position = position  # Current node (Node object)

    def can_complete_task(self, task):
        """Check if the helicopter can complete a given task."""
        return (
            (not task.visual_search or self.visual_search_capability) and
            self.load_capacity >= task.material_transport and
            self.medical_capacity >= task.medical_assistance and
            self.passenger_limit >= task.personnel_transfer
        )

    def complete_task(self, task, completion_time, total_tasks):
        """Complete a task if resources are sufficient and calculate benefit."""
        if self.can_complete_task(task):
            self.load_capacity -= task.material_transport
            self.medical_capacity -= task.medical_assistance
            self.passenger_limit -= task.personnel_transfer
            task.is_completed = True
            task.completion_time = completion_time
            # Pass total_tasks to calculate_benefit
            return task.calculate_benefit(completion_time, total_tasks)
        return 0

def initialize_graph():
    """Initialize the rescue graph with nodes, tasks, and helicopters."""
    # Define nodes
    central_node = Node("Central Base", 0, 0)  # Centralized base
    nodes = [
        central_node,
        Node("Node A", 20, 15),
        Node("Node B", 10, 5),
        Node("Node C", 30, 10),
        Node("Node D", 40, 20)
    ]

    # Add tasks to nodes
    tasks = [
        Task(task_id=1, visual_search=True, material_transport=200, medical_assistance=2, personnel_transfer=1, optimal_time=20, effective_time=40, ineffective_time=60),
        Task(task_id=2, visual_search=False, material_transport=300, medical_assistance=1, personnel_transfer=2, optimal_time=15, effective_time=30, ineffective_time=50),
        Task(task_id=3, visual_search=True, material_transport=100, medical_assistance=3, personnel_transfer=0, optimal_time=10, effective_time=25, ineffective_time=40),
        Task(task_id=4, visual_search=False, material_transport=200, medical_assistance=0, personnel_transfer=3, optimal_time=30, effective_time=50, ineffective_time=70),
        Task(task_id=5, visual_search=True, material_transport=150, medical_assistance=1, personnel_transfer=1, optimal_time=25, effective_time=45, ineffective_time=60),

    ]
    nodes[1].add_task(tasks[0])
    nodes[1].add_task(tasks[1])
    nodes[2].add_task(tasks[2])
    nodes[3].add_task(tasks[4])
    nodes[4].add_task(tasks[3])

    # Define helicopters stationed at the central base
    helicopters = [
        Helicopter(1, hovering=True, visual_search_capability=True, load_capacity=500, medical_capacity=3, passenger_limit=3, range_km=500, speed_kmh=150, position=central_node),
        Helicopter(2, hovering=True, visual_search_capability=False, load_capacity=500, medical_capacity=3, passenger_limit=3, range_km=500, speed_kmh=150, position=central_node),
    ]

    return nodes, helicopters

def assign_task_with_vt(helicopter, nodes, current_time, total_tasks):
    """
    Assign a task to the helicopter considering the new benefit function.
    """
    best_task = None
    best_task_node = None
    max_benefit = 0

    for node in nodes:
        for task in node.tasks:
            if not task.is_completed:
                # Calculate travel time to the task
                distance = helicopter.position.distance_to(node)
                travel_time = distance / helicopter.speed_kmh * 60  # Tiempo en minutos
                completion_time = current_time + travel_time

                # Check if the helicopter can complete the task
                if helicopter.can_complete_task(task):
                    # Calculate adjusted benefit (f * v_t)
                    benefit = task.calculate_benefit(completion_time, total_tasks)
                    if benefit > max_benefit:
                        max_benefit = benefit
                        best_task = task
                        best_task_node = node

    if best_task:
        # Move the helicopter to the task's node
        distance = helicopter.position.distance_to(best_task_node)
        travel_time = distance / helicopter.speed_kmh * 60  # Tiempo en minutos
        helicopter.position = best_task_node
        print(
            f"Assigned: Helicopter {helicopter.helicopter_id} to Task {best_task.task_id} at {best_task_node.name}. Flight time: {travel_time:.1f} minutes."
        )
        return best_task, travel_time
    else:
        print(f"No suitable tasks for Helicopter {helicopter.helicopter_id}.")
        return None, 0

def simulate_rescue_with_vt(nodes, helicopters, total_time):
    """
    Simulate the rescue operation with the adjusted benefit function (f * v_t).
    """
    current_time = 0
    total_tasks = sum(len(node.tasks) for node in nodes)  # Total number of tasks
    completed_tasks = 0  # Track completed tasks
    total_benefit = 0

    # Data for plotting
    completion_times = []
    individual_benefits = []
    helicopter_schedule = {helicopter.helicopter_id: [] for helicopter in helicopters}

    while current_time < total_time:
        for helicopter in helicopters:
            # Assign a task to the helicopter
            task, travel_time = assign_task_with_vt(helicopter, nodes, current_time, total_tasks)

            if task:
                # Update time and track task completion
                start_time = current_time
                current_time += travel_time
                task_completion_time = current_time

                # Complete the task and calculate benefit
                benefit = helicopter.complete_task(task, task_completion_time, total_tasks)
                total_benefit += benefit
                completed_tasks += 1

                # Store scheduling data
                helicopter_schedule[helicopter.helicopter_id].append((start_time, task_completion_time, task.task_id))

                # Store data for plotting
                completion_times.append(task_completion_time)
                individual_benefits.append(benefit)

                print(
                    f"Task {task.task_id} completed by Helicopter {helicopter.helicopter_id} at time {task_completion_time:.1f} minutes. Benefit: {benefit:.4f}"
                )

        # Increment the simulation time (if no tasks are assigned)
        current_time += 1

    print(f"\nSimulation completed. \nTotal tasks completed: {completed_tasks}/{total_tasks}. \nTotal benefit: {total_benefit:.4f}")
    
    # Calculate cumulative benefits
    cumulative_benefits = []
    total = 0
    for b in individual_benefits:
        total += b
        cumulative_benefits.append(total)
        
    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(completion_times, cumulative_benefits, marker="o", linestyle="-", label="Cumulative Benefit")
    plt.title("Cumulative Benefit Over Time - Greedy Algorithm", fontsize=14)
    plt.xlabel("Time (minutes)", fontsize=12)
    plt.ylabel("Cumulative Benefit", fontsize=12)
    plt.ylim(0, 0.8)
    plt.grid(True, linestyle="--", alpha=0.7)
    plt.legend(fontsize=12)
    plt.tight_layout()
    plt.show()

    # Plot scheduling (Gantt Chart)
    plot_schedule(helicopter_schedule)

def plot_schedule(helicopter_schedule):
    """
    Generate a Gantt chart showing the scheduling of tasks for helicopters.

    Parameters:
    - helicopter_schedule: A dictionary where each key is a helicopter ID, 
      and the value is a list of tuples (start_time, end_time, task_id).
    """
    fig, ax = plt.subplots(figsize=(12, 6))

    for helicopter_id, tasks in helicopter_schedule.items():
        for task in tasks:
            start_time, end_time, task_id = task
            ax.barh(
                y=helicopter_id, 
                width=(end_time - start_time), 
                left=start_time, 
                height=0.4, 
                align='center', 
                label=f"Task {task_id}" if helicopter_id == 1 else None
            )
            # Add the task label inside the bar
            ax.text(
                x=start_time + (end_time - start_time) / 2,
                y=helicopter_id,
                s=f"T{task_id}",
                va='center',
                ha='center',
                color='white',
                fontsize=8,
                fontweight='bold'
            )

    # Customization
    ax.set_title("Helicopter Task Scheduling", fontsize=14)
    ax.set_xlabel("Time (minutes)", fontsize=12)
    ax.set_ylabel("Helicopters", fontsize=12)
    ax.set_yticks(list(helicopter_schedule.keys()))
    ax.set_yticklabels([f"H{h_id}" for h_id in helicopter_schedule.keys()])
    ax.grid(True, linestyle="--", alpha=0.7)
    plt.tight_layout()
    plt.show()    
    
# Initialize the rescue graph
nodes, helicopters = initialize_graph()

# Run the simulation
simulate_rescue_with_vt(nodes, helicopters, total_time=40)
# Out:
# Assigned: Helicopter 1 to Task 1 at Node A. Flight time: 10.0 minutes.
# Task 1 completed by Helicopter 1 at time 10.0 minutes. Benefit: 0.2000
# Assigned: Helicopter 2 to Task 4 at Node D. Flight time: 17.9 minutes.
# Task 4 completed by Helicopter 2 at time 27.9 minutes. Benefit: 0.2000
# Assigned: Helicopter 1 to Task 5 at Node C. Flight time: 4.5 minutes.
# Task 5 completed by Helicopter 1 at time 33.4 minutes. Benefit: 0.0582
# No suitable tasks for Helicopter 2.
# No suitable tasks for Helicopter 1.
# No suitable tasks for Helicopter 2.
# No suitable tasks for Helicopter 1.
# No suitable tasks for Helicopter 2.
# No suitable tasks for Helicopter 1.
# No suitable tasks for Helicopter 2.
# No suitable tasks for Helicopter 1.
# No suitable tasks for Helicopter 2.
# No suitable tasks for Helicopter 1.
# No suitable tasks for Helicopter 2.
# No suitable tasks for Helicopter 1.
# No suitable tasks for Helicopter 2.
#
# Simulation completed.
# Total tasks completed: 3/5.
# Total benefit: 0.4582

# %%
import random
import math
import gym
from gym import spaces
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

class Node:
    """Represents a node (location) in the rescue graph."""
    def __init__(self, name, x, y):
        self.name = name
        self.x = x  # X-coordinate
        self.y = y  # Y-coordinate
        self.tasks = []  # Tasks at this node

    def add_task(self, task):
        """Add a task to this node."""
        self.tasks.append(task)

    def distance_to(self, other_node):
        """Calculate the distance to another node."""
        return math.sqrt((self.x - other_node.x)**2 + (self.y - other_node.y)**2)

class Task:
    """Represents a task at a node."""
    def __init__(self, task_id, visual_search, material_transport, medical_assistance, personnel_transfer, optimal_time, effective_time, ineffective_time):
        self.task_id = task_id  # Unique ID for the task
        self.visual_search = visual_search  # True/False if visual search is needed
        self.material_transport = material_transport  # Material weight required (kg)
        self.medical_assistance = medical_assistance  # Number of patients needing assistance
        self.personnel_transfer = personnel_transfer  # Number of personnel to transfer
        self.optimal_time = optimal_time  # Optimal rescue time for maximum benefit
        self.effective_time = effective_time  # Effective rescue time for reduced benefit
        self.ineffective_time = ineffective_time  # Time after which no benefit is awarded
        self.is_completed = False  # Track if task is completed
        self.completion_time = None  # Time when the task was completed

    def calculate_benefit(self, completion_time, total_tasks):
        """
        Calculate the benefit of completing a task.
        completion_time: Time at which the task is completed.
        total_tasks: Total number of tasks in the system (used to calculate v_t).
        """
        # Calculate time satisfaction (f)
        if completion_time <= self.optimal_time:
            f = 1
        elif completion_time <= self.effective_time:
            f = 0.5 * ((self.effective_time - completion_time) / (self.effective_time - self.optimal_time))
        elif completion_time <= self.ineffective_time:
            f = 0.5 * ((completion_time - self.effective_time) / (self.ineffective_time - self.effective_time))
        else:
            f = 0

        # Calculate v_t (task completion ratio)
        v_t = 1 / total_tasks  # Incremental contribution of completing one task
        return f * v_t

class Helicopter:
    """Represents a helicopter in the rescue fleet."""
    def __init__(self, helicopter_id, hovering, visual_search_capability, load_capacity, medical_capacity, passenger_limit, range_km, speed_kmh, position):
        self.helicopter_id = helicopter_id  # Unique ID
        self.hovering = hovering  # Whether it can hover (True/False)
        self.visual_search_capability = visual_search_capability  # True/False if visual search is possible
        self.load_capacity = load_capacity  # Maximum load in kg
        self.medical_capacity = medical_capacity  # Maximum medical assistance capacity
        self.passenger_limit = passenger_limit  # Maximum passengers
        self.range_km = range_km  # Maximum range in km
        self.speed_kmh = speed_kmh  # Speed in km/h
        self.position = position  # Current node (Node object)

    def can_complete_task(self, task):
        """Check if the helicopter can complete a given task."""
        return (
            (not task.visual_search or self.visual_search_capability) and
            self.load_capacity >= task.material_transport and
            self.medical_capacity >= task.medical_assistance and
            self.passenger_limit >= task.personnel_transfer
        )

    def complete_task(self, task, completion_time, total_tasks):
        """Complete a task if resources are sufficient and calculate benefit."""
        if self.can_complete_task(task):
            self.load_capacity -= task.material_transport
            self.medical_capacity -= task.medical_assistance
            self.passenger_limit -= task.personnel_transfer
            task.is_completed = True
            task.completion_time = completion_time
            # Pass total_tasks to calculate_benefit
            return task.calculate_benefit(completion_time, total_tasks)
        return 0

class RescueEnv(gym.Env):
    """Custom Gym environment for the rescue operation."""
    def __init__(self, nodes, helicopters, total_time):
        super(RescueEnv, self).__init__()
        self.nodes = nodes
        self.helicopters = helicopters
        self.total_time = total_time
        self.current_time = 0

        # Define observation and action space
        self.observation_space = spaces.Box(low=0, high=1, shape=(len(nodes) + len(helicopters),))
        self.action_space = spaces.Discrete(len(nodes))

    def reset(self):
        """Reset the environment to its initial state."""
        self.current_time = 0
        for node in self.nodes:
            for task in node.tasks:
                task.is_completed = False
                task.completion_time = None
        return self._get_state()

    def step(self, action):
        """Perform an action and return the new state, reward, and whether the simulation is done."""
        reward = 0
        done = self.current_time >= self.total_time

        if not done:
            helicopter = self.helicopters[action % len(self.helicopters)]
            node = self.nodes[action % len(self.nodes)]

            for task in node.tasks:
                if not task.is_completed and helicopter.can_complete_task(task):
                    travel_time = helicopter.position.distance_to(node) / helicopter.speed_kmh * 60
                    completion_time = self.current_time + travel_time
                    reward += helicopter.complete_task(task, completion_time, sum(len(n.tasks) for n in self.nodes))
                    helicopter.position = node
                    break

            self.current_time += 1

        return self._get_state(), reward, done, {}

    def _get_state(self):
        """Return the current state as a vector."""
        return np.array([len(node.tasks) for node in self.nodes] + [1 if h.hovering else 0 for h in self.helicopters])

# Actor-Critic model for PPO
class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(ActorCritic, self).__init__()
        self.actor = nn.Sequential(
            nn.Linear(state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, action_dim),
            nn.Softmax(dim=-1),
        )
        self.critic = nn.Sequential(
            nn.Linear(state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 1),
        )

    def forward(self, state):
        action_probs = self.actor(state)
        value = self.critic(state)
        return action_probs, value

# PPO training logic
class PPO:
    def __init__(self, env, gamma=0.99, lr=1e-3, eps_clip=0.2):
        self.env = env
        self.gamma = gamma
        self.eps_clip = eps_clip

        self.actor_critic = ActorCritic(
            state_dim=env.observation_space.shape[0],
            action_dim=env.action_space.n,
        )
        self.optimizer = optim.Adam(self.actor_critic.parameters(), lr=lr)
        self.loss_fn = nn.MSELoss()

        self.episode_rewards = []  # To track rewards per episode

    def train(self, episodes):
        for episode in range(episodes):
            state = self.env.reset()
            done = False
            episode_reward = 0  # Track reward for this episode

            while not done:
                state_tensor = torch.tensor(state, dtype=torch.float32)
                action_probs, value = self.actor_critic(state_tensor)
                dist = torch.distributions.Categorical(action_probs)
                action = dist.sample()

                next_state, reward, done, _ = self.env.step(action.item())
                episode_reward += reward  # Accumulate reward

                # Update policy and value networks here (using PPO update logic)

                state = next_state

            self.episode_rewards.append(episode_reward)  # Store total reward for this episode
            print(f"Episode {episode + 1}/{episodes}, Total Reward: {episode_reward:.4f}")


# Example of initializing the environment and running PPO
nodes = [
    Node("Central Base", 0, 0),
    Node("Node A", 10, 5),
    Node("Node B", 20, 15),
    Node("Node C", 30, 10),
    Node("Node D", 40, 20)
]

tasks = [
    Task(task_id=1, visual_search=True, material_transport=200, medical_assistance=2, personnel_transfer=1, optimal_time=20, effective_time=40, ineffective_time=60),
    Task(task_id=2, visual_search=False, material_transport=300, medical_assistance=1, personnel_transfer=2, optimal_time=15, effective_time=30, ineffective_time=50)
]

nodes[1].add_task(tasks[0])
nodes[2].add_task(tasks[1])

helicopters = [
    Helicopter(1, hovering=True, visual_search_capability=True, load_capacity=500, medical_capacity=3, passenger_limit=3, range_km=500, speed_kmh=150, position=nodes[0]),
    Helicopter(2, hovering=True, visual_search_capability=False, load_capacity=500, medical_capacity=3, passenger_limit=3, range_km=500, speed_kmh=150, position=nodes[0])
]

env = RescueEnv(nodes, helicopters, total_time=100)
ppo = PPO(env)
ppo.train(episodes=1000)

# After training is complete
plt.figure(figsize=(10, 6))
plt.plot(range(len(ppo.episode_rewards)), ppo.episode_rewards, label="Episode Reward")
plt.title("Benefit Over Episodes", fontsize=14)
plt.xlabel("Episodes", fontsize=12)
plt.ylabel("Total Benefit", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.7)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Episode 1/1000, Total Reward: 0.5000
# Episode 2/1000, Total Reward: 0.0000
# Episode 3/1000, Total Reward: 0.0000
# Episode 4/1000, Total Reward: 0.0000
# Episode 5/1000, Total Reward: 0.0000
# Episode 6/1000, Total Reward: 0.0000
# Episode 7/1000, Total Reward: 0.0000
# Episode 8/1000, Total Reward: 0.0000
# Episode 9/1000, Total Reward: 0.0000
# Episode 10/1000, Total Reward: 0.0000
# Episode 11/1000, Total Reward: 0.0000
# Episode 12/1000, Total Reward: 0.0000
# Episode 13/1000, Total Reward: 0.0000
# Episode 14/1000, Total Reward: 0.0000
# Episode 15/1000, Total Reward: 0.0000
# Episode 16/1000, Total Reward: 0.0000
# Episode 17/1000, Total Reward: 0.0000
# Episode 18/1000, Total Reward: 0.0000
# Episode 19/1000, Total Reward: 0.0000
# Episode 20/1000, Total Reward: 0.0000
# Episode 21/1000, Total Reward: 0.0000
# Episode 22/1000, Total Reward: 0.0000
# Episode 23/1000, Total Reward: 0.0000
# Episode 24/1000, Total Reward: 0.0000
# Episode 25/1000, Total Reward: 0.0000
# Episode 26/1000, Total Reward: 0.0000
# Episode 27/1000, Total Reward: 0.0000
# Episode 28/1000, Total Reward: 0.0000
# Episode 29/1000, Total Reward: 0.0000
# Episode 30/1000, Total Reward: 0.0000
# Episode 31/1000, Total Reward: 0.0000
# Episode 32/1000, Total Reward: 0.0000
# Episode 33/1000, Total Reward: 0.0000
# Episode 34/1000, Total Reward: 0.0000
# Episode 35/1000, Total Reward: 0.0000
# Episode 36/1000, Total Reward: 0.0000
# Episode 37/1000, Total Reward: 0.0000
# Episode 38/1000, Total Reward: 0.0000
# Episode 39/1000, Total Reward: 0.0000
# Episode 40/1000, Total Reward: 0.0000
# Episode 41/1000, Total Reward: 0.0000
# Episode 42/1000, Total Reward: 0.0000
# Episode 43/1000, Total Reward: 0.0000
# Episode 44/1000, Total Reward: 0.0000
# Episode 45/1000, Total Reward: 0.0000
# Episode 46/1000, Total Reward: 0.0000
# Episode 47/1000, Total Reward: 0.0000
# Episode 48/1000, Total Reward: 0.0000
# Episode 49/1000, Total Reward: 0.0000
# Episode 50/1000, Total Reward: 0.0000
# Episode 51/1000, Total Reward: 0.0000
# Episode 52/1000, Total Reward: 0.0000
# Episode 53/1000, Total Reward: 0.0000
# Episode 54/1000, Total Reward: 0.0000
# Episode 55/1000, Total Reward: 0.0000
# Episode 56/1000, Total Reward: 0.0000
# Episode 57/1000, Total Reward: 0.0000
# Episode 58/1000, Total Reward: 0.0000
# Episode 59/1000, Total Reward: 0.0000
# Episode 60/1000, Total Reward: 0.0000
# Episode 61/1000, Total Reward: 0.0000
# Episode 62/1000, Total Reward: 0.0000
# Episode 63/1000, Total Reward: 0.0000
# Episode 64/1000, Total Reward: 0.0000
# Episode 65/1000, Total Reward: 0.0000
# Episode 66/1000, Total Reward: 0.0000
# Episode 67/1000, Total Reward: 0.0000
# Episode 68/1000, Total Reward: 0.0000
# Episode 69/1000, Total Reward: 0.0000
# Episode 70/1000, Total Reward: 0.0000
# Episode 71/1000, Total Reward: 0.0000
# Episode 72/1000, Total Reward: 0.0000
# Episode 73/1000, Total Reward: 0.0000
# Episode 74/1000, Total Reward: 0.0000
# Episode 75/1000, Total Reward: 0.0000
# Episode 76/1000, Total Reward: 0.0000
# Episode 77/1000, Total Reward: 0.0000
# Episode 78/1000, Total Reward: 0.0000
# Episode 79/1000, Total Reward: 0.0000
# Episode 80/1000, Total Reward: 0.0000
# Episode 81/1000, Total Reward: 0.0000
# Episode 82/1000, Total Reward: 0.0000
# Episode 83/1000, Total Reward: 0.0000
# Episode 84/1000, Total Reward: 0.0000
# Episode 85/1000, Total Reward: 0.0000
# Episode 86/1000, Total Reward: 0.0000
# Episode 87/1000, Total Reward: 0.0000
# Episode 88/1000, Total Reward: 0.0000
# Episode 89/1000, Total Reward: 0.0000
# Episode 90/1000, Total Reward: 0.0000
# Episode 91/1000, Total Reward: 0.0000
# Episode 92/1000, Total Reward: 0.0000
# Episode 93/1000, Total Reward: 0.0000
# Episode 94/1000, Total Reward: 0.0000
# Episode 95/1000, Total Reward: 0.0000
# Episode 96/1000, Total Reward: 0.0000
# Episode 97/1000, Total Reward: 0.0000
# Episode 98/1000, Total Reward: 0.0000
# Episode 99/1000, Total Reward: 0.0000
# Episode 100/1000, Total Reward: 0.0000
# Episode 101/1000, Total Reward: 0.0000
# Episode 102/1000, Total Reward: 0.0000
# Episode 103/1000, Total Reward: 0.0000
# Episode 104/1000, Total Reward: 0.0000
# Episode 105/1000, Total Reward: 0.0000
# Episode 106/1000, Total Reward: 0.0000
# Episode 107/1000, Total Reward: 0.0000
# Episode 108/1000, Total Reward: 0.0000
# Episode 109/1000, Total Reward: 0.0000
# Episode 110/1000, Total Reward: 0.0000
# Episode 111/1000, Total Reward: 0.0000
# Episode 112/1000, Total Reward: 0.0000
# Episode 113/1000, Total Reward: 0.0000
# Episode 114/1000, Total Reward: 0.0000
# Episode 115/1000, Total Reward: 0.0000
# Episode 116/1000, Total Reward: 0.0000
# Episode 117/1000, Total Reward: 0.0000
# Episode 118/1000, Total Reward: 0.0000
# Episode 119/1000, Total Reward: 0.0000
# Episode 120/1000, Total Reward: 0.0000
# Episode 121/1000, Total Reward: 0.0000
# Episode 122/1000, Total Reward: 0.0000
# Episode 123/1000, Total Reward: 0.0000
# Episode 124/1000, Total Reward: 0.0000
# Episode 125/1000, Total Reward: 0.0000
# Episode 126/1000, Total Reward: 0.0000
# Episode 127/1000, Total Reward: 0.0000
# Episode 128/1000, Total Reward: 0.0000
# Episode 129/1000, Total Reward: 0.0000
# Episode 130/1000, Total Reward: 0.0000
# Episode 131/1000, Total Reward: 0.0000
# Episode 132/1000, Total Reward: 0.0000
# Episode 133/1000, Total Reward: 0.0000
# Episode 134/1000, Total Reward: 0.0000
# Episode 135/1000, Total Reward: 0.0000
# Episode 136/1000, Total Reward: 0.0000
# Episode 137/1000, Total Reward: 0.0000
# Episode 138/1000, Total Reward: 0.0000
# Episode 139/1000, Total Reward: 0.0000
# Episode 140/1000, Total Reward: 0.0000
# Episode 141/1000, Total Reward: 0.0000
# Episode 142/1000, Total Reward: 0.0000
# Episode 143/1000, Total Reward: 0.0000
# Episode 144/1000, Total Reward: 0.0000
# Episode 145/1000, Total Reward: 0.0000
# Episode 146/1000, Total Reward: 0.0000
# Episode 147/1000, Total Reward: 0.0000
# Episode 148/1000, Total Reward: 0.0000
# Episode 149/1000, Total Reward: 0.0000
# Episode 150/1000, Total Reward: 0.0000
# Episode 151/1000, Total Reward: 0.0000
# Episode 152/1000, Total Reward: 0.0000
# Episode 153/1000, Total Reward: 0.0000
# Episode 154/1000, Total Reward: 0.0000
# Episode 155/1000, Total Reward: 0.0000
# Episode 156/1000, Total Reward: 0.0000
# Episode 157/1000, Total Reward: 0.0000
# Episode 158/1000, Total Reward: 0.0000
# Episode 159/1000, Total Reward: 0.0000
# Episode 160/1000, Total Reward: 0.0000
# Episode 161/1000, Total Reward: 0.0000
# Episode 162/1000, Total Reward: 0.0000
# Episode 163/1000, Total Reward: 0.0000
# Episode 164/1000, Total Reward: 0.0000
# Episode 165/1000, Total Reward: 0.0000
# Episode 166/1000, Total Reward: 0.0000
# Episode 167/1000, Total Reward: 0.0000
# Episode 168/1000, Total Reward: 0.0000
# Episode 169/1000, Total Reward: 0.0000
# Episode 170/1000, Total Reward: 0.0000
# Episode 171/1000, Total Reward: 0.0000
# Episode 172/1000, Total Reward: 0.0000
# Episode 173/1000, Total Reward: 0.0000
# Episode 174/1000, Total Reward: 0.0000
# Episode 175/1000, Total Reward: 0.0000
# Episode 176/1000, Total Reward: 0.0000
# Episode 177/1000, Total Reward: 0.0000
# Episode 178/1000, Total Reward: 0.0000
# Episode 179/1000, Total Reward: 0.0000
# Episode 180/1000, Total Reward: 0.0000
# Episode 181/1000, Total Reward: 0.0000
# Episode 182/1000, Total Reward: 0.0000
# Episode 183/1000, Total Reward: 0.0000
# Episode 184/1000, Total Reward: 0.0000
# Episode 185/1000, Total Reward: 0.0000
# Episode 186/1000, Total Reward: 0.0000
# Episode 187/1000, Total Reward: 0.0000
# Episode 188/1000, Total Reward: 0.0000
# Episode 189/1000, Total Reward: 0.0000
# Episode 190/1000, Total Reward: 0.0000
# Episode 191/1000, Total Reward: 0.0000
# Episode 192/1000, Total Reward: 0.0000
# Episode 193/1000, Total Reward: 0.0000
# Episode 194/1000, Total Reward: 0.0000
# Episode 195/1000, Total Reward: 0.0000
# Episode 196/1000, Total Reward: 0.0000
# Episode 197/1000, Total Reward: 0.0000
# Episode 198/1000, Total Reward: 0.0000
# Episode 199/1000, Total Reward: 0.0000
# Episode 200/1000, Total Reward: 0.0000
# Episode 201/1000, Total Reward: 0.0000
# Episode 202/1000, Total Reward: 0.0000
# Episode 203/1000, Total Reward: 0.0000
# Episode 204/1000, Total Reward: 0.0000
# Episode 205/1000, Total Reward: 0.0000
# Episode 206/1000, Total Reward: 0.0000
# Episode 207/1000, Total Reward: 0.0000
# Episode 208/1000, Total Reward: 0.0000
# Episode 209/1000, Total Reward: 0.0000
# Episode 210/1000, Total Reward: 0.0000
# Episode 211/1000, Total Reward: 0.0000
# Episode 212/1000, Total Reward: 0.0000
# Episode 213/1000, Total Reward: 0.0000
# Episode 214/1000, Total Reward: 0.0000
# Episode 215/1000, Total Reward: 0.0000
# Episode 216/1000, Total Reward: 0.0000
# Episode 217/1000, Total Reward: 0.0000
# Episode 218/1000, Total Reward: 0.0000
# Episode 219/1000, Total Reward: 0.0000
# Episode 220/1000, Total Reward: 0.0000
# Episode 221/1000, Total Reward: 0.0000
# Episode 222/1000, Total Reward: 0.0000
# Episode 223/1000, Total Reward: 0.0000
# Episode 224/1000, Total Reward: 0.0000
# Episode 225/1000, Total Reward: 0.0000
# Episode 226/1000, Total Reward: 0.0000
# Episode 227/1000, Total Reward: 0.0000
# Episode 228/1000, Total Reward: 0.0000
# Episode 229/1000, Total Reward: 0.0000
# Episode 230/1000, Total Reward: 0.0000
# Episode 231/1000, Total Reward: 0.0000
# Episode 232/1000, Total Reward: 0.0000
# Episode 233/1000, Total Reward: 0.0000
# Episode 234/1000, Total Reward: 0.0000
# Episode 235/1000, Total Reward: 0.0000
# Episode 236/1000, Total Reward: 0.0000
# Episode 237/1000, Total Reward: 0.0000
# Episode 238/1000, Total Reward: 0.0000
# Episode 239/1000, Total Reward: 0.0000
# Episode 240/1000, Total Reward: 0.0000
# Episode 241/1000, Total Reward: 0.0000
# Episode 242/1000, Total Reward: 0.0000
# Episode 243/1000, Total Reward: 0.0000
# Episode 244/1000, Total Reward: 0.0000
# Episode 245/1000, Total Reward: 0.0000
# Episode 246/1000, Total Reward: 0.0000
# Episode 247/1000, Total Reward: 0.0000
# Episode 248/1000, Total Reward: 0.0000
# Episode 249/1000, Total Reward: 0.0000
# Episode 250/1000, Total Reward: 0.0000
# Episode 251/1000, Total Reward: 0.0000
# Episode 252/1000, Total Reward: 0.0000
# Episode 253/1000, Total Reward: 0.0000
# Episode 254/1000, Total Reward: 0.0000
# Episode 255/1000, Total Reward: 0.0000
# Episode 256/1000, Total Reward: 0.0000
# Episode 257/1000, Total Reward: 0.0000
# Episode 258/1000, Total Reward: 0.0000
# Episode 259/1000, Total Reward: 0.0000
# Episode 260/1000, Total Reward: 0.0000
# Episode 261/1000, Total Reward: 0.0000
# Episode 262/1000, Total Reward: 0.0000
# Episode 263/1000, Total Reward: 0.0000
# Episode 264/1000, Total Reward: 0.0000
# Episode 265/1000, Total Reward: 0.0000
# Episode 266/1000, Total Reward: 0.0000
# Episode 267/1000, Total Reward: 0.0000
# Episode 268/1000, Total Reward: 0.0000
# Episode 269/1000, Total Reward: 0.0000
# Episode 270/1000, Total Reward: 0.0000
# Episode 271/1000, Total Reward: 0.0000
# Episode 272/1000, Total Reward: 0.0000
# Episode 273/1000, Total Reward: 0.0000
# Episode 274/1000, Total Reward: 0.0000
# Episode 275/1000, Total Reward: 0.0000
# Episode 276/1000, Total Reward: 0.0000
# Episode 277/1000, Total Reward: 0.0000
# Episode 278/1000, Total Reward: 0.0000
# Episode 279/1000, Total Reward: 0.0000
# Episode 280/1000, Total Reward: 0.0000
# Episode 281/1000, Total Reward: 0.0000
# Episode 282/1000, Total Reward: 0.0000
# Episode 283/1000, Total Reward: 0.0000
# Episode 284/1000, Total Reward: 0.0000
# Episode 285/1000, Total Reward: 0.0000
# Episode 286/1000, Total Reward: 0.0000
# Episode 287/1000, Total Reward: 0.0000
# Episode 288/1000, Total Reward: 0.0000
# Episode 289/1000, Total Reward: 0.0000
# Episode 290/1000, Total Reward: 0.0000
# Episode 291/1000, Total Reward: 0.0000
# Episode 292/1000, Total Reward: 0.0000
# Episode 293/1000, Total Reward: 0.0000
# Episode 294/1000, Total Reward: 0.0000
# Episode 295/1000, Total Reward: 0.0000
# Episode 296/1000, Total Reward: 0.0000
# Episode 297/1000, Total Reward: 0.0000
# Episode 298/1000, Total Reward: 0.0000
# Episode 299/1000, Total Reward: 0.0000
# Episode 300/1000, Total Reward: 0.0000
# Episode 301/1000, Total Reward: 0.0000
# Episode 302/1000, Total Reward: 0.0000
# Episode 303/1000, Total Reward: 0.0000
# Episode 304/1000, Total Reward: 0.0000
# Episode 305/1000, Total Reward: 0.0000
# Episode 306/1000, Total Reward: 0.0000
# Episode 307/1000, Total Reward: 0.0000
# Episode 308/1000, Total Reward: 0.0000
# Episode 309/1000, Total Reward: 0.0000
# Episode 310/1000, Total Reward: 0.0000
# Episode 311/1000, Total Reward: 0.0000
# Episode 312/1000, Total Reward: 0.0000
# Episode 313/1000, Total Reward: 0.0000
# Episode 314/1000, Total Reward: 0.0000
# Episode 315/1000, Total Reward: 0.0000
# Episode 316/1000, Total Reward: 0.0000
# Episode 317/1000, Total Reward: 0.0000
# Episode 318/1000, Total Reward: 0.0000
# Episode 319/1000, Total Reward: 0.0000
# Episode 320/1000, Total Reward: 0.0000
# Episode 321/1000, Total Reward: 0.0000
# Episode 322/1000, Total Reward: 0.0000
# Episode 323/1000, Total Reward: 0.0000
# Episode 324/1000, Total Reward: 0.0000
# Episode 325/1000, Total Reward: 0.0000
# Episode 326/1000, Total Reward: 0.0000
# Episode 327/1000, Total Reward: 0.0000
# Episode 328/1000, Total Reward: 0.0000
# Episode 329/1000, Total Reward: 0.0000
# Episode 330/1000, Total Reward: 0.0000
# Episode 331/1000, Total Reward: 0.0000
# Episode 332/1000, Total Reward: 0.0000
# Episode 333/1000, Total Reward: 0.0000
# Episode 334/1000, Total Reward: 0.0000
# Episode 335/1000, Total Reward: 0.0000
# Episode 336/1000, Total Reward: 0.0000
# Episode 337/1000, Total Reward: 0.0000
# Episode 338/1000, Total Reward: 0.0000
# Episode 339/1000, Total Reward: 0.0000
# Episode 340/1000, Total Reward: 0.0000
# Episode 341/1000, Total Reward: 0.0000
# Episode 342/1000, Total Reward: 0.0000
# Episode 343/1000, Total Reward: 0.0000
# Episode 344/1000, Total Reward: 0.0000
# Episode 345/1000, Total Reward: 0.0000
# Episode 346/1000, Total Reward: 0.0000
# Episode 347/1000, Total Reward: 0.0000
# Episode 348/1000, Total Reward: 0.0000
# Episode 349/1000, Total Reward: 0.0000
# Episode 350/1000, Total Reward: 0.0000
# Episode 351/1000, Total Reward: 0.0000
# Episode 352/1000, Total Reward: 0.0000
# Episode 353/1000, Total Reward: 0.0000
# Episode 354/1000, Total Reward: 0.0000
# Episode 355/1000, Total Reward: 0.0000
# Episode 356/1000, Total Reward: 0.0000
# Episode 357/1000, Total Reward: 0.0000
# Episode 358/1000, Total Reward: 0.0000
# Episode 359/1000, Total Reward: 0.0000
# Episode 360/1000, Total Reward: 0.0000
# Episode 361/1000, Total Reward: 0.0000
# Episode 362/1000, Total Reward: 0.0000
# Episode 363/1000, Total Reward: 0.0000
# Episode 364/1000, Total Reward: 0.0000
# Episode 365/1000, Total Reward: 0.0000
# Episode 366/1000, Total Reward: 0.0000
# Episode 367/1000, Total Reward: 0.0000
# Episode 368/1000, Total Reward: 0.0000
# Episode 369/1000, Total Reward: 0.0000
# Episode 370/1000, Total Reward: 0.0000
# Episode 371/1000, Total Reward: 0.0000
# Episode 372/1000, Total Reward: 0.0000
# Episode 373/1000, Total Reward: 0.0000
# Episode 374/1000, Total Reward: 0.0000
# Episode 375/1000, Total Reward: 0.0000
# Episode 376/1000, Total Reward: 0.0000
# Episode 377/1000, Total Reward: 0.0000
# Episode 378/1000, Total Reward: 0.0000
# Episode 379/1000, Total Reward: 0.0000
# Episode 380/1000, Total Reward: 0.0000
# Episode 381/1000, Total Reward: 0.0000
# Episode 382/1000, Total Reward: 0.0000
# Episode 383/1000, Total Reward: 0.0000
# Episode 384/1000, Total Reward: 0.0000
# Episode 385/1000, Total Reward: 0.0000
# Episode 386/1000, Total Reward: 0.0000
# Episode 387/1000, Total Reward: 0.0000
# Episode 388/1000, Total Reward: 0.0000
# Episode 389/1000, Total Reward: 0.0000
# Episode 390/1000, Total Reward: 0.0000
# Episode 391/1000, Total Reward: 0.0000
# Episode 392/1000, Total Reward: 0.0000
# Episode 393/1000, Total Reward: 0.0000
# Episode 394/1000, Total Reward: 0.0000
# Episode 395/1000, Total Reward: 0.0000
# Episode 396/1000, Total Reward: 0.0000
# Episode 397/1000, Total Reward: 0.0000
# Episode 398/1000, Total Reward: 0.0000
# Episode 399/1000, Total Reward: 0.0000
# Episode 400/1000, Total Reward: 0.0000
# Episode 401/1000, Total Reward: 0.0000
# Episode 402/1000, Total Reward: 0.0000
# Episode 403/1000, Total Reward: 0.0000
# Episode 404/1000, Total Reward: 0.0000
# Episode 405/1000, Total Reward: 0.0000
# Episode 406/1000, Total Reward: 0.0000
# Episode 407/1000, Total Reward: 0.0000
# Episode 408/1000, Total Reward: 0.0000
# Episode 409/1000, Total Reward: 0.0000
# Episode 410/1000, Total Reward: 0.0000
# Episode 411/1000, Total Reward: 0.0000
# Episode 412/1000, Total Reward: 0.0000
# Episode 413/1000, Total Reward: 0.0000
# Episode 414/1000, Total Reward: 0.0000
# Episode 415/1000, Total Reward: 0.0000
# Episode 416/1000, Total Reward: 0.0000
# Episode 417/1000, Total Reward: 0.0000
# Episode 418/1000, Total Reward: 0.0000
# Episode 419/1000, Total Reward: 0.0000
# Episode 420/1000, Total Reward: 0.0000
# Episode 421/1000, Total Reward: 0.0000
# Episode 422/1000, Total Reward: 0.0000
# Episode 423/1000, Total Reward: 0.0000
# Episode 424/1000, Total Reward: 0.0000
# Episode 425/1000, Total Reward: 0.0000
# Episode 426/1000, Total Reward: 0.0000
# Episode 427/1000, Total Reward: 0.0000
# Episode 428/1000, Total Reward: 0.0000
# Episode 429/1000, Total Reward: 0.0000
# Episode 430/1000, Total Reward: 0.0000
# Episode 431/1000, Total Reward: 0.0000
# Episode 432/1000, Total Reward: 0.0000
# Episode 433/1000, Total Reward: 0.0000
# Episode 434/1000, Total Reward: 0.0000
# Episode 435/1000, Total Reward: 0.0000
# Episode 436/1000, Total Reward: 0.0000
# Episode 437/1000, Total Reward: 0.0000
# Episode 438/1000, Total Reward: 0.0000
# Episode 439/1000, Total Reward: 0.0000
# Episode 440/1000, Total Reward: 0.0000
# Episode 441/1000, Total Reward: 0.0000
# Episode 442/1000, Total Reward: 0.0000
# Episode 443/1000, Total Reward: 0.0000
# Episode 444/1000, Total Reward: 0.0000
# Episode 445/1000, Total Reward: 0.0000
# Episode 446/1000, Total Reward: 0.0000
# Episode 447/1000, Total Reward: 0.0000
# Episode 448/1000, Total Reward: 0.0000
# Episode 449/1000, Total Reward: 0.0000
# Episode 450/1000, Total Reward: 0.0000
# Episode 451/1000, Total Reward: 0.0000
# Episode 452/1000, Total Reward: 0.0000
# Episode 453/1000, Total Reward: 0.0000
# Episode 454/1000, Total Reward: 0.0000
# Episode 455/1000, Total Reward: 0.0000
# Episode 456/1000, Total Reward: 0.0000
# Episode 457/1000, Total Reward: 0.0000
# Episode 458/1000, Total Reward: 0.0000
# Episode 459/1000, Total Reward: 0.0000
# Episode 460/1000, Total Reward: 0.0000
# Episode 461/1000, Total Reward: 0.0000
# Episode 462/1000, Total Reward: 0.0000
# Episode 463/1000, Total Reward: 0.0000
# Episode 464/1000, Total Reward: 0.0000
# Episode 465/1000, Total Reward: 0.0000
# Episode 466/1000, Total Reward: 0.0000
# Episode 467/1000, Total Reward: 0.0000
# Episode 468/1000, Total Reward: 0.0000
# Episode 469/1000, Total Reward: 0.0000
# Episode 470/1000, Total Reward: 0.0000
# Episode 471/1000, Total Reward: 0.0000
# Episode 472/1000, Total Reward: 0.0000
# Episode 473/1000, Total Reward: 0.0000
# Episode 474/1000, Total Reward: 0.0000
# Episode 475/1000, Total Reward: 0.0000
# Episode 476/1000, Total Reward: 0.0000
# Episode 477/1000, Total Reward: 0.0000
# Episode 478/1000, Total Reward: 0.0000
# Episode 479/1000, Total Reward: 0.0000
# Episode 480/1000, Total Reward: 0.0000
# Episode 481/1000, Total Reward: 0.0000
# Episode 482/1000, Total Reward: 0.0000
# Episode 483/1000, Total Reward: 0.0000
# Episode 484/1000, Total Reward: 0.0000
# Episode 485/1000, Total Reward: 0.0000
# Episode 486/1000, Total Reward: 0.0000
# Episode 487/1000, Total Reward: 0.0000
# Episode 488/1000, Total Reward: 0.0000
# Episode 489/1000, Total Reward: 0.0000
# Episode 490/1000, Total Reward: 0.0000
# Episode 491/1000, Total Reward: 0.0000
# Episode 492/1000, Total Reward: 0.0000
# Episode 493/1000, Total Reward: 0.0000
# Episode 494/1000, Total Reward: 0.0000
# Episode 495/1000, Total Reward: 0.0000
# Episode 496/1000, Total Reward: 0.0000
# Episode 497/1000, Total Reward: 0.0000
# Episode 498/1000, Total Reward: 0.0000
# Episode 499/1000, Total Reward: 0.0000
# Episode 500/1000, Total Reward: 0.0000
# Episode 501/1000, Total Reward: 0.0000
# Episode 502/1000, Total Reward: 0.0000
# Episode 503/1000, Total Reward: 0.0000
# Episode 504/1000, Total Reward: 0.0000
# Episode 505/1000, Total Reward: 0.0000
# Episode 506/1000, Total Reward: 0.0000
# Episode 507/1000, Total Reward: 0.0000
# Episode 508/1000, Total Reward: 0.0000
# Episode 509/1000, Total Reward: 0.0000
# Episode 510/1000, Total Reward: 0.0000
# Episode 511/1000, Total Reward: 0.0000
# Episode 512/1000, Total Reward: 0.0000
# Episode 513/1000, Total Reward: 0.0000
# Episode 514/1000, Total Reward: 0.0000
# Episode 515/1000, Total Reward: 0.0000
# Episode 516/1000, Total Reward: 0.0000
# Episode 517/1000, Total Reward: 0.0000
# Episode 518/1000, Total Reward: 0.0000
# Episode 519/1000, Total Reward: 0.0000
# Episode 520/1000, Total Reward: 0.0000
# Episode 521/1000, Total Reward: 0.0000
# Episode 522/1000, Total Reward: 0.0000
# Episode 523/1000, Total Reward: 0.0000
# Episode 524/1000, Total Reward: 0.0000
# Episode 525/1000, Total Reward: 0.0000
# Episode 526/1000, Total Reward: 0.0000
# Episode 527/1000, Total Reward: 0.0000
# Episode 528/1000, Total Reward: 0.0000
# Episode 529/1000, Total Reward: 0.0000
# Episode 530/1000, Total Reward: 0.0000
# Episode 531/1000, Total Reward: 0.0000
# Episode 532/1000, Total Reward: 0.0000
# Episode 533/1000, Total Reward: 0.0000
# Episode 534/1000, Total Reward: 0.0000
# Episode 535/1000, Total Reward: 0.0000
# Episode 536/1000, Total Reward: 0.0000
# Episode 537/1000, Total Reward: 0.0000
# Episode 538/1000, Total Reward: 0.0000
# Episode 539/1000, Total Reward: 0.0000
# Episode 540/1000, Total Reward: 0.0000
# Episode 541/1000, Total Reward: 0.0000
# Episode 542/1000, Total Reward: 0.0000
# Episode 543/1000, Total Reward: 0.0000
# Episode 544/1000, Total Reward: 0.0000
# Episode 545/1000, Total Reward: 0.0000
# Episode 546/1000, Total Reward: 0.0000
# Episode 547/1000, Total Reward: 0.0000
# Episode 548/1000, Total Reward: 0.0000
# Episode 549/1000, Total Reward: 0.0000
# Episode 550/1000, Total Reward: 0.0000
# Episode 551/1000, Total Reward: 0.0000
# Episode 552/1000, Total Reward: 0.0000
# Episode 553/1000, Total Reward: 0.0000
# Episode 554/1000, Total Reward: 0.0000
# Episode 555/1000, Total Reward: 0.0000
# Episode 556/1000, Total Reward: 0.0000
# Episode 557/1000, Total Reward: 0.0000
# Episode 558/1000, Total Reward: 0.0000
# Episode 559/1000, Total Reward: 0.0000
# Episode 560/1000, Total Reward: 0.0000
# Episode 561/1000, Total Reward: 0.0000
# Episode 562/1000, Total Reward: 0.0000
# Episode 563/1000, Total Reward: 0.0000
# Episode 564/1000, Total Reward: 0.0000
# Episode 565/1000, Total Reward: 0.0000
# Episode 566/1000, Total Reward: 0.0000
# Episode 567/1000, Total Reward: 0.0000
# Episode 568/1000, Total Reward: 0.0000
# Episode 569/1000, Total Reward: 0.0000
# Episode 570/1000, Total Reward: 0.0000
# Episode 571/1000, Total Reward: 0.0000
# Episode 572/1000, Total Reward: 0.0000
# Episode 573/1000, Total Reward: 0.0000
# Episode 574/1000, Total Reward: 0.0000
# Episode 575/1000, Total Reward: 0.0000
# Episode 576/1000, Total Reward: 0.0000
# Episode 577/1000, Total Reward: 0.0000
# Episode 578/1000, Total Reward: 0.0000
# Episode 579/1000, Total Reward: 0.0000
# Episode 580/1000, Total Reward: 0.0000
# Episode 581/1000, Total Reward: 0.0000
# Episode 582/1000, Total Reward: 0.0000
# Episode 583/1000, Total Reward: 0.0000
# Episode 584/1000, Total Reward: 0.0000
# Episode 585/1000, Total Reward: 0.0000
# Episode 586/1000, Total Reward: 0.0000
# Episode 587/1000, Total Reward: 0.0000
# Episode 588/1000, Total Reward: 0.0000
# Episode 589/1000, Total Reward: 0.0000
# Episode 590/1000, Total Reward: 0.0000
# Episode 591/1000, Total Reward: 0.0000
# Episode 592/1000, Total Reward: 0.0000
# Episode 593/1000, Total Reward: 0.0000
# Episode 594/1000, Total Reward: 0.0000
# Episode 595/1000, Total Reward: 0.0000
# Episode 596/1000, Total Reward: 0.0000
# Episode 597/1000, Total Reward: 0.0000
# Episode 598/1000, Total Reward: 0.0000
# Episode 599/1000, Total Reward: 0.0000
# Episode 600/1000, Total Reward: 0.0000
# Episode 601/1000, Total Reward: 0.0000
# Episode 602/1000, Total Reward: 0.0000
# Episode 603/1000, Total Reward: 0.0000
# Episode 604/1000, Total Reward: 0.0000
# Episode 605/1000, Total Reward: 0.0000
# Episode 606/1000, Total Reward: 0.0000
# Episode 607/1000, Total Reward: 0.0000
# Episode 608/1000, Total Reward: 0.0000
# Episode 609/1000, Total Reward: 0.0000
# Episode 610/1000, Total Reward: 0.0000
# Episode 611/1000, Total Reward: 0.0000
# Episode 612/1000, Total Reward: 0.0000
# Episode 613/1000, Total Reward: 0.0000
# Episode 614/1000, Total Reward: 0.0000
# Episode 615/1000, Total Reward: 0.0000
# Episode 616/1000, Total Reward: 0.0000
# Episode 617/1000, Total Reward: 0.0000
# Episode 618/1000, Total Reward: 0.0000
# Episode 619/1000, Total Reward: 0.0000
# Episode 620/1000, Total Reward: 0.0000
# Episode 621/1000, Total Reward: 0.0000
# Episode 622/1000, Total Reward: 0.0000
# Episode 623/1000, Total Reward: 0.0000
# Episode 624/1000, Total Reward: 0.0000
# Episode 625/1000, Total Reward: 0.0000
# Episode 626/1000, Total Reward: 0.0000
# Episode 627/1000, Total Reward: 0.0000
# Episode 628/1000, Total Reward: 0.0000
# Episode 629/1000, Total Reward: 0.0000
# Episode 630/1000, Total Reward: 0.0000
# Episode 631/1000, Total Reward: 0.0000
# Episode 632/1000, Total Reward: 0.0000
# Episode 633/1000, Total Reward: 0.0000
# Episode 634/1000, Total Reward: 0.0000
# Episode 635/1000, Total Reward: 0.0000
# Episode 636/1000, Total Reward: 0.0000
# Episode 637/1000, Total Reward: 0.0000
# Episode 638/1000, Total Reward: 0.0000
# Episode 639/1000, Total Reward: 0.0000
# Episode 640/1000, Total Reward: 0.0000
# Episode 641/1000, Total Reward: 0.0000
# Episode 642/1000, Total Reward: 0.0000
# Episode 643/1000, Total Reward: 0.0000
# Episode 644/1000, Total Reward: 0.0000
# Episode 645/1000, Total Reward: 0.0000
# Episode 646/1000, Total Reward: 0.0000
# Episode 647/1000, Total Reward: 0.0000
# Episode 648/1000, Total Reward: 0.0000
# Episode 649/1000, Total Reward: 0.0000
# Episode 650/1000, Total Reward: 0.0000
# Episode 651/1000, Total Reward: 0.0000
# Episode 652/1000, Total Reward: 0.0000
# Episode 653/1000, Total Reward: 0.0000
# Episode 654/1000, Total Reward: 0.0000
# Episode 655/1000, Total Reward: 0.0000
# Episode 656/1000, Total Reward: 0.0000
# Episode 657/1000, Total Reward: 0.0000
# Episode 658/1000, Total Reward: 0.0000
# Episode 659/1000, Total Reward: 0.0000
# Episode 660/1000, Total Reward: 0.0000
# Episode 661/1000, Total Reward: 0.0000
# Episode 662/1000, Total Reward: 0.0000
# Episode 663/1000, Total Reward: 0.0000
# Episode 664/1000, Total Reward: 0.0000
# Episode 665/1000, Total Reward: 0.0000
# Episode 666/1000, Total Reward: 0.0000
# Episode 667/1000, Total Reward: 0.0000
# Episode 668/1000, Total Reward: 0.0000
# Episode 669/1000, Total Reward: 0.0000
# Episode 670/1000, Total Reward: 0.0000
# Episode 671/1000, Total Reward: 0.0000
# Episode 672/1000, Total Reward: 0.0000
# Episode 673/1000, Total Reward: 0.0000
# Episode 674/1000, Total Reward: 0.0000
# Episode 675/1000, Total Reward: 0.0000
# Episode 676/1000, Total Reward: 0.0000
# Episode 677/1000, Total Reward: 0.0000
# Episode 678/1000, Total Reward: 0.0000
# Episode 679/1000, Total Reward: 0.0000
# Episode 680/1000, Total Reward: 0.0000
# Episode 681/1000, Total Reward: 0.0000
# Episode 682/1000, Total Reward: 0.0000
# Episode 683/1000, Total Reward: 0.0000
# Episode 684/1000, Total Reward: 0.0000
# Episode 685/1000, Total Reward: 0.0000
# Episode 686/1000, Total Reward: 0.0000
# Episode 687/1000, Total Reward: 0.0000
# Episode 688/1000, Total Reward: 0.0000
# Episode 689/1000, Total Reward: 0.0000
# Episode 690/1000, Total Reward: 0.0000
# Episode 691/1000, Total Reward: 0.0000
# Episode 692/1000, Total Reward: 0.0000
# Episode 693/1000, Total Reward: 0.0000
# Episode 694/1000, Total Reward: 0.0000
# Episode 695/1000, Total Reward: 0.0000
# Episode 696/1000, Total Reward: 0.0000
# Episode 697/1000, Total Reward: 0.0000
# Episode 698/1000, Total Reward: 0.0000
# Episode 699/1000, Total Reward: 0.0000
# Episode 700/1000, Total Reward: 0.0000
# Episode 701/1000, Total Reward: 0.0000
# Episode 702/1000, Total Reward: 0.0000
# Episode 703/1000, Total Reward: 0.0000
# Episode 704/1000, Total Reward: 0.0000
# Episode 705/1000, Total Reward: 0.0000
# Episode 706/1000, Total Reward: 0.0000
# Episode 707/1000, Total Reward: 0.0000
# Episode 708/1000, Total Reward: 0.0000
# Episode 709/1000, Total Reward: 0.0000
# Episode 710/1000, Total Reward: 0.0000
# Episode 711/1000, Total Reward: 0.0000
# Episode 712/1000, Total Reward: 0.0000
# Episode 713/1000, Total Reward: 0.0000
# Episode 714/1000, Total Reward: 0.0000
# Episode 715/1000, Total Reward: 0.0000
# Episode 716/1000, Total Reward: 0.0000
# Episode 717/1000, Total Reward: 0.0000
# Episode 718/1000, Total Reward: 0.0000
# Episode 719/1000, Total Reward: 0.0000
# Episode 720/1000, Total Reward: 0.0000
# Episode 721/1000, Total Reward: 0.0000
# Episode 722/1000, Total Reward: 0.0000
# Episode 723/1000, Total Reward: 0.0000
# Episode 724/1000, Total Reward: 0.0000
# Episode 725/1000, Total Reward: 0.0000
# Episode 726/1000, Total Reward: 0.0000
# Episode 727/1000, Total Reward: 0.0000
# Episode 728/1000, Total Reward: 0.0000
# Episode 729/1000, Total Reward: 0.0000
# Episode 730/1000, Total Reward: 0.0000
# Episode 731/1000, Total Reward: 0.0000
# Episode 732/1000, Total Reward: 0.0000
# Episode 733/1000, Total Reward: 0.0000
# Episode 734/1000, Total Reward: 0.0000
# Episode 735/1000, Total Reward: 0.0000
# Episode 736/1000, Total Reward: 0.0000
# Episode 737/1000, Total Reward: 0.0000
# Episode 738/1000, Total Reward: 0.0000
# Episode 739/1000, Total Reward: 0.0000
# Episode 740/1000, Total Reward: 0.0000
# Episode 741/1000, Total Reward: 0.0000
# Episode 742/1000, Total Reward: 0.0000
# Episode 743/1000, Total Reward: 0.0000
# Episode 744/1000, Total Reward: 0.0000
# Episode 745/1000, Total Reward: 0.0000
# Episode 746/1000, Total Reward: 0.0000
# Episode 747/1000, Total Reward: 0.0000
# Episode 748/1000, Total Reward: 0.0000
# Episode 749/1000, Total Reward: 0.0000
# Episode 750/1000, Total Reward: 0.0000
# Episode 751/1000, Total Reward: 0.0000
# Episode 752/1000, Total Reward: 0.0000
# Episode 753/1000, Total Reward: 0.0000
# Episode 754/1000, Total Reward: 0.0000
# Episode 755/1000, Total Reward: 0.0000
# Episode 756/1000, Total Reward: 0.0000
# Episode 757/1000, Total Reward: 0.0000
# Episode 758/1000, Total Reward: 0.0000
# Episode 759/1000, Total Reward: 0.0000
# Episode 760/1000, Total Reward: 0.0000
# Episode 761/1000, Total Reward: 0.0000
# Episode 762/1000, Total Reward: 0.0000
# Episode 763/1000, Total Reward: 0.0000
# Episode 764/1000, Total Reward: 0.0000
# Episode 765/1000, Total Reward: 0.0000
# Episode 766/1000, Total Reward: 0.0000
# Episode 767/1000, Total Reward: 0.0000
# Episode 768/1000, Total Reward: 0.0000
# Episode 769/1000, Total Reward: 0.0000
# Episode 770/1000, Total Reward: 0.0000
# Episode 771/1000, Total Reward: 0.0000
# Episode 772/1000, Total Reward: 0.0000
# Episode 773/1000, Total Reward: 0.0000
# Episode 774/1000, Total Reward: 0.0000
# Episode 775/1000, Total Reward: 0.0000
# Episode 776/1000, Total Reward: 0.0000
# Episode 777/1000, Total Reward: 0.0000
# Episode 778/1000, Total Reward: 0.0000
# Episode 779/1000, Total Reward: 0.0000
# Episode 780/1000, Total Reward: 0.0000
# Episode 781/1000, Total Reward: 0.0000
# Episode 782/1000, Total Reward: 0.0000
# Episode 783/1000, Total Reward: 0.0000
# Episode 784/1000, Total Reward: 0.0000
# Episode 785/1000, Total Reward: 0.0000
# Episode 786/1000, Total Reward: 0.0000
# Episode 787/1000, Total Reward: 0.0000
# Episode 788/1000, Total Reward: 0.0000
# Episode 789/1000, Total Reward: 0.0000
# Episode 790/1000, Total Reward: 0.0000
# Episode 791/1000, Total Reward: 0.0000
# Episode 792/1000, Total Reward: 0.0000
# Episode 793/1000, Total Reward: 0.0000
# Episode 794/1000, Total Reward: 0.0000
# Episode 795/1000, Total Reward: 0.0000
# Episode 796/1000, Total Reward: 0.0000
# Episode 797/1000, Total Reward: 0.0000
# Episode 798/1000, Total Reward: 0.0000
# Episode 799/1000, Total Reward: 0.0000
# Episode 800/1000, Total Reward: 0.0000
# Episode 801/1000, Total Reward: 0.0000
# Episode 802/1000, Total Reward: 0.0000
# Episode 803/1000, Total Reward: 0.0000
# Episode 804/1000, Total Reward: 0.0000
# Episode 805/1000, Total Reward: 0.0000
# Episode 806/1000, Total Reward: 0.0000
# Episode 807/1000, Total Reward: 0.0000
# Episode 808/1000, Total Reward: 0.0000
# Episode 809/1000, Total Reward: 0.0000
# Episode 810/1000, Total Reward: 0.0000
# Episode 811/1000, Total Reward: 0.0000
# Episode 812/1000, Total Reward: 0.0000
# Episode 813/1000, Total Reward: 0.0000
# Episode 814/1000, Total Reward: 0.0000
# Episode 815/1000, Total Reward: 0.0000
# Episode 816/1000, Total Reward: 0.0000
# Episode 817/1000, Total Reward: 0.0000
# Episode 818/1000, Total Reward: 0.0000
# Episode 819/1000, Total Reward: 0.0000
# Episode 820/1000, Total Reward: 0.0000
# Episode 821/1000, Total Reward: 0.0000
# Episode 822/1000, Total Reward: 0.0000
# Episode 823/1000, Total Reward: 0.0000
# Episode 824/1000, Total Reward: 0.0000
# Episode 825/1000, Total Reward: 0.0000
# Episode 826/1000, Total Reward: 0.0000
# Episode 827/1000, Total Reward: 0.0000
# Episode 828/1000, Total Reward: 0.0000
# Episode 829/1000, Total Reward: 0.0000
# Episode 830/1000, Total Reward: 0.0000
# Episode 831/1000, Total Reward: 0.0000
# Episode 832/1000, Total Reward: 0.0000
# Episode 833/1000, Total Reward: 0.0000
# Episode 834/1000, Total Reward: 0.0000
# Episode 835/1000, Total Reward: 0.0000
# Episode 836/1000, Total Reward: 0.0000
# Episode 837/1000, Total Reward: 0.0000
# Episode 838/1000, Total Reward: 0.0000
# Episode 839/1000, Total Reward: 0.0000
# Episode 840/1000, Total Reward: 0.0000
# Episode 841/1000, Total Reward: 0.0000
# Episode 842/1000, Total Reward: 0.0000
# Episode 843/1000, Total Reward: 0.0000
# Episode 844/1000, Total Reward: 0.0000
# Episode 845/1000, Total Reward: 0.0000
# Episode 846/1000, Total Reward: 0.0000
# Episode 847/1000, Total Reward: 0.0000
# Episode 848/1000, Total Reward: 0.0000
# Episode 849/1000, Total Reward: 0.0000
# Episode 850/1000, Total Reward: 0.0000
# Episode 851/1000, Total Reward: 0.0000
# Episode 852/1000, Total Reward: 0.0000
# Episode 853/1000, Total Reward: 0.0000
# Episode 854/1000, Total Reward: 0.0000
# Episode 855/1000, Total Reward: 0.0000
# Episode 856/1000, Total Reward: 0.0000
# Episode 857/1000, Total Reward: 0.0000
# Episode 858/1000, Total Reward: 0.0000
# Episode 859/1000, Total Reward: 0.0000
# Episode 860/1000, Total Reward: 0.0000
# Episode 861/1000, Total Reward: 0.0000
# Episode 862/1000, Total Reward: 0.0000
# Episode 863/1000, Total Reward: 0.0000
# Episode 864/1000, Total Reward: 0.0000
# Episode 865/1000, Total Reward: 0.0000
# Episode 866/1000, Total Reward: 0.0000
# Episode 867/1000, Total Reward: 0.0000
# Episode 868/1000, Total Reward: 0.0000
# Episode 869/1000, Total Reward: 0.0000
# Episode 870/1000, Total Reward: 0.0000
# Episode 871/1000, Total Reward: 0.0000
# Episode 872/1000, Total Reward: 0.0000
# Episode 873/1000, Total Reward: 0.0000
# Episode 874/1000, Total Reward: 0.0000
# Episode 875/1000, Total Reward: 0.0000
# Episode 876/1000, Total Reward: 0.0000
# Episode 877/1000, Total Reward: 0.0000
# Episode 878/1000, Total Reward: 0.0000
# Episode 879/1000, Total Reward: 0.0000
# Episode 880/1000, Total Reward: 0.0000
# Episode 881/1000, Total Reward: 0.0000
# Episode 882/1000, Total Reward: 0.0000
# Episode 883/1000, Total Reward: 0.0000
# Episode 884/1000, Total Reward: 0.0000
# Episode 885/1000, Total Reward: 0.0000
# Episode 886/1000, Total Reward: 0.0000
# Episode 887/1000, Total Reward: 0.0000
# Episode 888/1000, Total Reward: 0.0000
# Episode 889/1000, Total Reward: 0.0000
# Episode 890/1000, Total Reward: 0.0000
# Episode 891/1000, Total Reward: 0.0000
# Episode 892/1000, Total Reward: 0.0000
# Episode 893/1000, Total Reward: 0.0000
# Episode 894/1000, Total Reward: 0.0000
# Episode 895/1000, Total Reward: 0.0000
# Episode 896/1000, Total Reward: 0.0000
# Episode 897/1000, Total Reward: 0.0000
# Episode 898/1000, Total Reward: 0.0000
# Episode 899/1000, Total Reward: 0.0000
# Episode 900/1000, Total Reward: 0.0000
# Episode 901/1000, Total Reward: 0.0000
# Episode 902/1000, Total Reward: 0.0000
# Episode 903/1000, Total Reward: 0.0000
# Episode 904/1000, Total Reward: 0.0000
# Episode 905/1000, Total Reward: 0.0000
# Episode 906/1000, Total Reward: 0.0000
# Episode 907/1000, Total Reward: 0.0000
# Episode 908/1000, Total Reward: 0.0000
# Episode 909/1000, Total Reward: 0.0000
# Episode 910/1000, Total Reward: 0.0000
# Episode 911/1000, Total Reward: 0.0000
# Episode 912/1000, Total Reward: 0.0000
# Episode 913/1000, Total Reward: 0.0000
# Episode 914/1000, Total Reward: 0.0000
# Episode 915/1000, Total Reward: 0.0000
# Episode 916/1000, Total Reward: 0.0000
# Episode 917/1000, Total Reward: 0.0000
# Episode 918/1000, Total Reward: 0.0000
# Episode 919/1000, Total Reward: 0.0000
# Episode 920/1000, Total Reward: 0.0000
# Episode 921/1000, Total Reward: 0.0000
# Episode 922/1000, Total Reward: 0.0000
# Episode 923/1000, Total Reward: 0.0000
# Episode 924/1000, Total Reward: 0.0000
# Episode 925/1000, Total Reward: 0.0000
# Episode 926/1000, Total Reward: 0.0000
# Episode 927/1000, Total Reward: 0.0000
# Episode 928/1000, Total Reward: 0.0000
# Episode 929/1000, Total Reward: 0.0000
# Episode 930/1000, Total Reward: 0.0000
# Episode 931/1000, Total Reward: 0.0000
# Episode 932/1000, Total Reward: 0.0000
# Episode 933/1000, Total Reward: 0.0000
# Episode 934/1000, Total Reward: 0.0000
# Episode 935/1000, Total Reward: 0.0000
# Episode 936/1000, Total Reward: 0.0000
# Episode 937/1000, Total Reward: 0.0000
# Episode 938/1000, Total Reward: 0.0000
# Episode 939/1000, Total Reward: 0.0000
# Episode 940/1000, Total Reward: 0.0000
# Episode 941/1000, Total Reward: 0.0000
# Episode 942/1000, Total Reward: 0.0000
# Episode 943/1000, Total Reward: 0.0000
# Episode 944/1000, Total Reward: 0.0000
# Episode 945/1000, Total Reward: 0.0000
# Episode 946/1000, Total Reward: 0.0000
# Episode 947/1000, Total Reward: 0.0000
# Episode 948/1000, Total Reward: 0.0000
# Episode 949/1000, Total Reward: 0.0000
# Episode 950/1000, Total Reward: 0.0000
# Episode 951/1000, Total Reward: 0.0000
# Episode 952/1000, Total Reward: 0.0000
# Episode 953/1000, Total Reward: 0.0000
# Episode 954/1000, Total Reward: 0.0000
# Episode 955/1000, Total Reward: 0.0000
# Episode 956/1000, Total Reward: 0.0000
# Episode 957/1000, Total Reward: 0.0000
# Episode 958/1000, Total Reward: 0.0000
# Episode 959/1000, Total Reward: 0.0000
# Episode 960/1000, Total Reward: 0.0000
# Episode 961/1000, Total Reward: 0.0000
# Episode 962/1000, Total Reward: 0.0000
# Episode 963/1000, Total Reward: 0.0000
# Episode 964/1000, Total Reward: 0.0000
# Episode 965/1000, Total Reward: 0.0000
# Episode 966/1000, Total Reward: 0.0000
# Episode 967/1000, Total Reward: 0.0000
# Episode 968/1000, Total Reward: 0.0000
# Episode 969/1000, Total Reward: 0.0000
# Episode 970/1000, Total Reward: 0.0000
# Episode 971/1000, Total Reward: 0.0000
# Episode 972/1000, Total Reward: 0.0000
# Episode 973/1000, Total Reward: 0.0000
# Episode 974/1000, Total Reward: 0.0000
# Episode 975/1000, Total Reward: 0.0000
# Episode 976/1000, Total Reward: 0.0000
# Episode 977/1000, Total Reward: 0.0000
# Episode 978/1000, Total Reward: 0.0000
# Episode 979/1000, Total Reward: 0.0000
# Episode 980/1000, Total Reward: 0.0000
# Episode 981/1000, Total Reward: 0.0000
# Episode 982/1000, Total Reward: 0.0000
# Episode 983/1000, Total Reward: 0.0000
# Episode 984/1000, Total Reward: 0.0000
# Episode 985/1000, Total Reward: 0.0000
# Episode 986/1000, Total Reward: 0.0000
# Episode 987/1000, Total Reward: 0.0000
# Episode 988/1000, Total Reward: 0.0000
# Episode 989/1000, Total Reward: 0.0000
# Episode 990/1000, Total Reward: 0.0000
# Episode 991/1000, Total Reward: 0.0000
# Episode 992/1000, Total Reward: 0.0000
# Episode 993/1000, Total Reward: 0.0000
# Episode 994/1000, Total Reward: 0.0000
# Episode 995/1000, Total Reward: 0.0000
# Episode 996/1000, Total Reward: 0.0000
# Episode 997/1000, Total Reward: 0.0000
# Episode 998/1000, Total Reward: 0.0000
# Episode 999/1000, Total Reward: 0.0000
# Episode 1000/1000, Total Reward: 0.0000
